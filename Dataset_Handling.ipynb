# %% [markdown]
# Import and Setups

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install rasterio numpy
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio) (2025.7.14)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.11/dist-packages (from rasterio) (8.2.1)
# Collecting cligj>=0.5 (from rasterio)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio)
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from rasterio) (3.2.3)
# Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 79.7 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Installing collected packages: cligj, click-plugins, affine, rasterio
# Successfully installed affine-2.4.0 click-plugins-1.1.1.2 cligj-0.7.2 rasterio-1.4.3

# %%
import os
import numpy as np
import rasterio
from rasterio.enums import Resampling
from rasterio.errors import NotGeoreferencedWarning
import warnings

# %% [markdown]
# Identify Nan and Inf values in the dataset and replace them.

# %%
#  Suppress georeferencing warnings
warnings.filterwarnings("ignore", category=NotGeoreferencedWarning)

#  Set your image folder path (modify this for your case)
image_dir = "/content/drive/MyDrive/Sentinel_training"

#  Loop through all TIF files
for filename in os.listdir(image_dir):
    if filename.lower().endswith(".tif"):
        filepath = os.path.join(image_dir, filename)
        print(f"Checking {filename}...")

        # Open and read the image
        with rasterio.open(filepath, "r+") as dataset:
            data = dataset.read().astype(np.float32)
            nan_mask = np.isnan(data)
            inf_mask = np.isinf(data)

            num_nan = nan_mask.sum()
            num_inf = inf_mask.sum()

            if num_nan > 0 or num_inf > 0:
                print(f"  ⚠️ Found NaNs: {num_nan}, Infs: {num_inf} → Replacing with 0.0")

                # Replace NaNs and Infs with 0
                data = np.nan_to_num(data, nan=0.0, posinf=0.0, neginf=0.0)

                # Overwrite the file in-place
                dataset.write(data.astype(dataset.dtypes[0]))
                print(f"  ✅ Fixed and saved: {filename}")
            else:
                print(f"  ✅ No issues found.")

print("✅ Finished checking and fixing all GeoTIFFs.")
# Out:
# Checking Sentinel_AllBands_Training_Id_1.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_2.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_17.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_19.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_18.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_32.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_33.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_38.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_36.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_37.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_39.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_40.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_45.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_44.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_46.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_56.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_57.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_55.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_58.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_59.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_60.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_62.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_63.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_61.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_64.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_67.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_68.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_66.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_69.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_73.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_74.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_65.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_71.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_75.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_77.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_78.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_76.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_79.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_88.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_89.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_99.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_100.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_98.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_101.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_102.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_103.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_85.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_105.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_106.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_108.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_107.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_110.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_114.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_115.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_118.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_120.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_111.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_123.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_124.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_135.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_141.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_144.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_146.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_145.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_149.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_148.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_150.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_152.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_151.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_155.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_154.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_156.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_157.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_160.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_161.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_162.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_163.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_169.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_165.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_172.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_176.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_179.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_175.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_131.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_10.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_136.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_137.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_132.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_11.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_125.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_121.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_130.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_126.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_139.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_138.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_182.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_147.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_143.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_21.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_20.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_22.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_30.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_31.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_23.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_28.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_9.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_42.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_41.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_183.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_184.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_185.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_186.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_187.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_188.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_189.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_190.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_192.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_194.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_196.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_197.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_198.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_199.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_200.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_201.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_202.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_203.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_204.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_205.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_206.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_207.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_208.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_209.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_210.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_211.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_213.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_214.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_215.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_216.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_217.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_218.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_219.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_220.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_221.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_222.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_223.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_224.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_225.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_227.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_228.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_229.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_212.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_195.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_226.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1211.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1216.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1217.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1219.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1222.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1224.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1226.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1227.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1228.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1229.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1231.tif...
#   ⚠️ Found NaNs: 4725, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1231.tif
# Checking Sentinel_AllBands_Training_Id_1232.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1233.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1234.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1236.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1237.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1239.tif...
#   ⚠️ Found NaNs: 4725, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1239.tif
# Checking Sentinel_AllBands_Training_Id_1240.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1241.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1242.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1244.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1245.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1248.tif...
#   ⚠️ Found NaNs: 4734, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_
Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1644.tif
# Checking Sentinel_AllBands_Training_Id_1645.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1646.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1647.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1649.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1650.tif...
#   ⚠️ Found NaNs: 4617, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1650.tif
# Checking Sentinel_AllBands_Training_Id_1000.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1001.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1002.tif...
#   ⚠️ Found NaNs: 4689, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1002.tif
# Checking Sentinel_AllBands_Training_Id_1003.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1005.tif...
#   ⚠️ Found NaNs: 4680, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1005.tif
# Checking Sentinel_AllBands_Training_Id_1006.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1008.tif...
#   ⚠️ Found NaNs: 9, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1008.tif
# Checking Sentinel_AllBands_Training_Id_1009.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1011.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1012.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1013.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1014.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1017.tif...
#   ⚠️ Found NaNs: 4689, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1017.tif
# Checking Sentinel_AllBands_Training_Id_1018.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1020.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1022.tif...
#   ⚠️ Found NaNs: 4689, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1022.tif
# Checking Sentinel_AllBands_Training_Id_1023.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1024.tif...
#   ⚠️ Found NaNs: 4689, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1024.tif
# Checking Sentinel_AllBands_Training_Id_1025.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1028.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1029.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1030.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1031.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1032.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1033.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1034.tif...
#   ⚠️ Found NaNs: 4689, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1034.tif
# Checking Sentinel_AllBands_Training_Id_1035.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1036.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1037.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1039.tif...
#   ⚠️ Found NaNs: 4698, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1039.tif
# Checking Sentinel_AllBands_Training_Id_1040.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1042.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1046.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1047.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1049.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1050.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1051.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1052.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1053.tif...
#   ⚠️ Found NaNs: 4689, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1053.tif
# Checking Sentinel_AllBands_Training_Id_1054.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1056.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1057.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1058.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1059.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1060.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1061.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1062.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1063.tif...
#   ⚠️ Found NaNs: 4689, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1063.tif
# Checking Sentinel_AllBands_Training_Id_1064.tif...
#   ⚠️ Found NaNs: 4689, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1064.tif
# Checking Sentinel_AllBands_Training_Id_1065.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1066.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1067.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1070.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1072.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1073.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1074.tif...
#   ⚠️ Found NaNs: 4698, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1074.tif
# Checking Sentinel_AllBands_Training_Id_1075.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1076.tif...
#   ⚠️ Found NaNs: 4698, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1076.tif
# Checking Sentinel_AllBands_Training_Id_1077.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1078.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1079.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1080.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1081.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1082.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1084.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1085.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1086.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1087.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1088.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1089.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1090.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1091.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1092.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1093.tif...
#   ⚠️ Found NaNs: 4707, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1093.tif
# Checking Sentinel_AllBands_Training_Id_1094.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1095.tif...
#   ⚠️ Found NaNs: 4698, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1095.tif
# Checking Sentinel_AllBands_Training_Id_1096.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1097.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1098.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1099.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1100.tif...
#   ⚠️ Found NaNs: 4707, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1100.tif
# Checking Sentinel_AllBands_Training_Id_1101.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1103.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1104.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1105.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1106.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1107.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1108.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1109.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1111.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1112.tif...
#   ⚠️ Found NaNs: 9324, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1112.tif
# Checking Sentinel_AllBands_Training_Id_1113.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1114.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1115.tif...
#   ⚠️ Found NaNs: 4698, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1115.tif
# Checking Sentinel_AllBands_Training_Id_1116.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1117.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1118.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1119.tif...
#   ⚠️ Found NaNs: 4698, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1119.tif
# Checking Sentinel_AllBands_Training_Id_1120.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1122.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1123.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1124.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1126.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1127.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1128.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1130.tif...
#   ⚠️ Found NaNs: 4698, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1130.tif
# Checking Sentinel_AllBands_Training_Id_1133.tif...
#   ⚠️ Found NaNs: 4707, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1133.tif
# Checking Sentinel_AllBands_Training_Id_1135.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1138.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1140.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1141.tif...
#   ⚠️ Found NaNs: 4707, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1141.tif
# Checking Sentinel_AllBands_Training_Id_1142.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1143.tif...
# ...
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1188.tif
# Checking Sentinel_AllBands_Training_Id_1191.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1192.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1193.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1194.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1196.tif...
#   ⚠️ Found NaNs: 4716, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1196.tif
# Checking Sentinel_AllBands_Training_Id_1197.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1198.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1200.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1201.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1202.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1203.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1204.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1205.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1206.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1207.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1208.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1209.tif...
#   ⚠️ Found NaNs: 4725, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1209.tif
# Checking Sentinel_AllBands_Training_Id_800.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_801.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_802.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_803.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_804.tif...
#   ⚠️ Found NaNs: 4653, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_804.tif
# Checking Sentinel_AllBands_Training_Id_806.tif...
#   ⚠️ Found NaNs: 4653, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_806.tif
# Checking Sentinel_AllBands_Training_Id_807.tif...
#   ⚠️ Found NaNs: 4662, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_807.tif
# Checking Sentinel_AllBands_Training_Id_808.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_809.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_810.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_811.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_812.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_813.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_814.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_815.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_816.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_818.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_820.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_821.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_822.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_823.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_824.tif...
#   ⚠️ Found NaNs: 4662, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_824.tif
# Checking Sentinel_AllBands_Training_Id_825.tif...
#   ⚠️ Found NaNs: 9, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_825.tif
# Checking Sentinel_AllBands_Training_Id_826.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_827.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_828.tif...
#   ⚠️ Found NaNs: 18, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_828.tif
# Checking Sentinel_AllBands_Training_Id_829.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_830.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_831.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_832.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_833.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_834.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_835.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_836.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_837.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_838.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_839.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_840.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_842.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_843.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_844.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_845.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_846.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_847.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_848.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_849.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_850.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_851.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_852.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_853.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_854.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_855.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_856.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_857.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_858.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_859.tif...
#   ⚠️ Found NaNs: 4662, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_859.tif
# Checking Sentinel_AllBands_Training_Id_860.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_862.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_863.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_864.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_869.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_871.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_872.tif...
#   ⚠️ Found NaNs: 4671, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_872.tif
# Checking Sentinel_AllBands_Training_Id_873.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_874.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_875.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_876.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_877.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_878.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_879.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_882.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_883.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_884.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_885.tif...
#   ⚠️ Found NaNs: 4671, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_885.tif
# Checking Sentinel_AllBands_Training_Id_886.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_887.tif...
#   ⚠️ Found NaNs: 4671, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_887.tif
# Checking Sentinel_AllBands_Training_Id_888.tif...
#   ⚠️ Found NaNs: 4662, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_888.tif
# Checking Sentinel_AllBands_Training_Id_889.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_890.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_891.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_892.tif...
#   ⚠️ Found NaNs: 4662, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_892.tif
# Checking Sentinel_AllBands_Training_Id_894.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_895.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_898.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_899.tif...
#   ⚠️ Found NaNs: 4671, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_899.tif
# Checking Sentinel_AllBands_Training_Id_900.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_901.tif...
#   ⚠️ Found NaNs: 4671, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_901.tif
# Checking Sentinel_AllBands_Training_Id_902.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_904.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_907.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_910.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_911.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_912.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_913.tif...
#   ⚠️ Found NaNs: 4671, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_913.tif
# Checking Sentinel_AllBands_Training_Id_915.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_916.tif...
#   ⚠️ Found NaNs: 4671, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_916.tif
# Checking Sentinel_AllBands_Training_Id_917.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_919.tif...
#   ⚠️ Found NaNs: 267462, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_919.tif
# Checking Sentinel_AllBands_Training_Id_920.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_921.tif...
#   ⚠️ Found NaNs: 4671, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_921.tif
# Checking Sentinel_AllBands_Training_Id_922.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_923.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_924.tif...
#   ⚠️ Found NaNs: 4671, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_924.tif
# Checking Sentinel_AllBands_Training_Id_926.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_927.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_929.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_930.tif...
#   ⚠️ Found NaNs: 4671, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_930.tif
# Checking Sentinel_AllBands_Training_Id_931.tif...
#   ⚠️ Found NaNs: 4671, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_931.tif
# Checking Sentinel_AllBands_Training_Id_932.tif...
#   ⚠️ Found NaNs: 4680, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_932.tif
# Checking Sentinel_AllBands_Training_Id_933.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_934.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_935.tif...
#   ⚠️ Found NaNs: 4671, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_935.tif
# Checking Sentinel_AllBands_Training_Id_936.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_937.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_938.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_939.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_940.tif...
#   ⚠️ Found NaNs: 18, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_940.tif
# Checking Sentinel_AllBands_Training_Id_941.tif...
#   ⚠️ Found NaNs: 18, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_941.tif
# Checking Sentinel_AllBands_Training_Id_942.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_943.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_944.tif...
#   ⚠️ Found NaNs: 4671, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_944.tif
# Checking Sentinel_AllBands_Training_Id_945.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_946.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_947.tif...
#   ⚠️ Found NaNs: 4671, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_947.tif
# Checking Sentinel_AllBands_Training_Id_948.tif...
#   ⚠️ Found NaNs: 4680, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_948.tif
# Checking Sentinel_AllBands_Training_Id_949.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_950.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_955.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_956.tif...
#   ⚠️ Found NaNs: 4626, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_956.tif
# Checking Sentinel_AllBands_Training_Id_959.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_960.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_961.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_962.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_964.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_965.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_966.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_967.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_968.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_969.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_971.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_972.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_973.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_976.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_978.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_979.tif...
#   ⚠️ Found NaNs: 4680, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_979.tif
# Checking Sentinel_AllBands_Training_Id_981.tif...
#   ⚠️ Found NaNs: 4680, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_981.tif
# Checking Sentinel_AllBands_Training_Id_983.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_984.tif...
#   ⚠️ Found NaNs: 4680, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_984.tif
# Checking Sentinel_AllBands_Training_Id_985.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_987.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_988.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_989.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_990.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_991.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_992.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_993.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_994.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_995.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_996.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_998.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_999.tif...
#   ✅ No issues found.
# Checking Sentinel_AllBands_Training_Id_1210.tif...
#   ⚠️ Found NaNs: 4725, Infs: 0 → Replacing with 0.0
#   ✅ Fixed and saved: Sentinel_AllBands_Training_Id_1210.tif
# ✅ Finished checking and fixing all GeoTIFFs.

# %% [markdown]
# Check for mismatched pairs.

# %%
image_dir = "/content/drive/MyDrive/P2 - Amazon ITU - PESU/GEE_Exports_all"
mask_dir = "/content/drive/MyDrive/P2 - Amazon ITU - PESU/All_Masks_TIF"

bad_pairs = []

for img_name in os.listdir(image_dir):
    if not img_name.endswith(".tif"):
        continue
    mask_name = img_name.replace("id_", "[01]_id_")
    img_path = os.path.join(image_dir, img_name)
    mask_path = os.path.join(mask_dir, mask_name)

    if not os.path.exists(mask_path):
        print(f"❌ Mask not found for {img_name}")
        continue

    with rasterio.open(img_path) as img_src, rasterio.open(mask_path) as mask_src:
        img_shape = (img_src.height, img_src.width)
        mask_shape = (mask_src.height, mask_src.width)

        if img_shape != mask_shape:
            print(f"⚠️ Mismatch: {img_name} → Image: {img_shape}, Mask: {mask_shape}")
            bad_pairs.append((img_path, mask_path))

print(f"\n🔎 Found {len(bad_pairs)} mismatched pairs.")
# Out:
# ❌ Mask not found for id_1185.tif
# ❌ Mask not found for id_472.tif
# ❌ Mask not found for id_478.tif
# ❌ Mask not found for id_115.tif
# ❌ Mask not found for id_1017.tif
# ❌ Mask not found for id_94.tif
# ❌ Mask not found for id_823.tif
# ❌ Mask not found for id_1183.tif
# ❌ Mask not found for id_818.tif
# ❌ Mask not found for id_91.tif
# ❌ Mask not found for id_1025.tif
# ❌ Mask not found for id_1182.tif
# ❌ Mask not found for id_89.tif
    with rasterio.open(image_path) as img_src, rasterio.open(mask_path) as mask_src:
        image_shape = (img_src.height, img_src.width)

        mask_data = mask_src.read(
            out_shape=(mask_src.count, image_shape[0], image_shape[1]),
            resampling=Resampling.nearest
        )

        transform = mask_src.transform
        transform = mask_src.transform * mask_src.transform.scale(
            (mask_src.width / mask_data.shape[-1]),
            (mask_src.height / mask_data.shape[-2])
        )

        profile = mask_src.profile
        profile.update(height=image_shape[0], width=image_shape[1], transform=transform)

        save_path = output_path if output_path else mask_path
        with rasterio.open(save_path, "w", **profile) as dst:
            dst.write(mask_data)

# %%
for img_path, mask_path in bad_pairs:
    print(f"Resizing mask: {mask_path}")
    resize_mask_to_match_image(img_path, mask_path)
# Out:
# Resizing mask: /content/drive/MyDrive/training_masks/Mask_Buffer20m_Id_212.tif
# Resizing mask: /content/drive/MyDrive/training_masks/Mask_Buffer20m_Id_195.tif
# Resizing mask: /content/drive/MyDrive/training_masks/Mask_Buffer20m_Id_226.tif

# %% [markdown]
# Copy masks to new folder removing runway-no runway information.

# %%
import shutil
import re

# 📁 Set paths
source_folder = "/content/drive/MyDrive/P2 - Amazon ITU - PESU/All_Masks_TIF"   # <- Change this
destination_folder = "/content/drive/MyDrive/Masks 800-1650"

# 📌 Make sure destination exists
os.makedirs(destination_folder, exist_ok=True)

# 🧠 Pattern to extract ID from filenames like "0_id_800.tif"
pattern = re.compile(r"[01]_id_(\d+)\.tif")

# 🔁 Iterate over all files in the source folder
for filename in os.listdir(source_folder):
    if filename.endswith(".tif"):
        match = pattern.match(filename)
        if match:
            id_number = int(match.group(1))
            if 800 <= id_number <= 1650:
                new_filename = f"Mask_Buffer20m_Id_{id_number}.tif"
                src_path = os.path.join(source_folder, filename)
                dst_path = os.path.join(destination_folder, new_filename)

                shutil.copyfile(src_path, dst_path)
                print(f"✅ Copied: {filename} → {new_filename}")

print("🎉 Done copying and renaming mask files.")
# Out:
# ✅ Copied: 0_id_1211.tif → Mask_Buffer20m_Id_1211.tif
# ✅ Copied: 0_id_1216.tif → Mask_Buffer20m_Id_1216.tif
# ✅ Copied: 1_id_1217.tif → Mask_Buffer20m_Id_1217.tif
# ✅ Copied: 1_id_1219.tif → Mask_Buffer20m_Id_1219.tif
# ✅ Copied: 1_id_1222.tif → Mask_Buffer20m_Id_1222.tif
# ✅ Copied: 0_id_1224.tif → Mask_Buffer20m_Id_1224.tif
# ✅ Copied: 0_id_1226.tif → Mask_Buffer20m_Id_1226.tif
# ✅ Copied: 0_id_1227.tif → Mask_Buffer20m_Id_1227.tif
# ✅ Copied: 0_id_1228.tif → Mask_Buffer20m_Id_1228.tif
# ✅ Copied: 1_id_1229.tif → Mask_Buffer20m_Id_1229.tif
# ✅ Copied: 0_id_1231.tif → Mask_Buffer20m_Id_1231.tif
# ✅ Copied: 1_id_1232.tif → Mask_Buffer20m_Id_1232.tif
# ✅ Copied: 0_id_1233.tif → Mask_Buffer20m_Id_1233.tif
# ✅ Copied: 0_id_1234.tif → Mask_Buffer20m_Id_1234.tif
# ✅ Copied: 1_id_1236.tif → Mask_Buffer20m_Id_1236.tif
# ✅ Copied: 0_id_1237.tif → Mask_Buffer20m_Id_1237.tif
# ✅ Copied: 1_id_1239.tif → Mask_Buffer20m_Id_1239.tif
# ✅ Copied: 1_id_1240.tif → Mask_Buffer20m_Id_1240.tif
# ✅ Copied: 0_id_1241.tif → Mask_Buffer20m_Id_1241.tif
# ✅ Copied: 0_id_1242.tif → Mask_Buffer20m_Id_1242.tif
# ✅ Copied: 1_id_1244.tif → Mask_Buffer20m_Id_1244.tif
# ✅ Copied: 1_id_1245.tif → Mask_Buffer20m_Id_1245.tif
# ✅ Copied: 0_id_1248.tif → Mask_Buffer20m_Id_1248.tif
# ✅ Copied: 1_id_1252.tif → Mask_Buffer20m_Id_1252.tif
# ✅ Copied: 0_id_1254.tif → Mask_Buffer20m_Id_1254.tif
# ✅ Copied: 1_id_1255.tif → Mask_Buffer20m_Id_1255.tif
# ✅ Copied: 1_id_1256.tif → Mask_Buffer20m_Id_1256.tif
# ✅ Copied: 0_id_1258.tif → Mask_Buffer20m_Id_1258.tif
# ✅ Copied: 0_id_1260.tif → Mask_Buffer20m_Id_1260.tif
# ✅ Copied: 0_id_1261.tif → Mask_Buffer20m_Id_1261.tif
# ✅ Copied: 0_id_1262.tif → Mask_Buffer20m_Id_1262.tif
# ✅ Copied: 1_id_1263.tif → Mask_Buffer20m_Id_1263.tif
# ✅ Copied: 0_id_1265.tif → Mask_Buffer20m_Id_1265.tif
# ✅ Copied: 1_id_1266.tif → Mask_Buffer20m_Id_1266.tif
# ✅ Copied: 1_id_1267.tif → Mask_Buffer20m_Id_1267.tif
# ✅ Copied: 0_id_1268.tif → Mask_Buffer20m_Id_1268.tif
# ✅ Copied: 1_id_1270.tif → Mask_Buffer20m_Id_1270.tif
# ✅ Copied: 0_id_1271.tif → Mask_Buffer20m_Id_1271.tif
# ✅ Copied: 0_id_1272.tif → Mask_Buffer20m_Id_1272.tif
# ✅ Copied: 0_id_1273.tif → Mask_Buffer20m_Id_1273.tif
# ✅ Copied: 0_id_1275.tif → Mask_Buffer20m_Id_1275.tif
# ✅ Copied: 1_id_1277.tif → Mask_Buffer20m_Id_1277.tif
# ✅ Copied: 0_id_1278.tif → Mask_Buffer20m_Id_1278.tif
# ✅ Copied: 1_id_1279.tif → Mask_Buffer20m_Id_1279.tif
# ✅ Copied: 0_id_1281.tif → Mask_Buffer20m_Id_1281.tif
# ✅ Copied: 1_id_1282.tif → Mask_Buffer20m_Id_1282.tif
# ✅ Copied: 0_id_1283.tif → Mask_Buffer20m_Id_1283.tif
# ✅ Copied: 0_id_1284.tif → Mask_Buffer20m_Id_1284.tif
# ✅ Copied: 1_id_1286.tif → Mask_Buffer20m_Id_1286.tif
# ✅ Copied: 1_id_1287.tif → Mask_Buffer20m_Id_1287.tif
# ✅ Copied: 0_id_1291.tif → Mask_Buffer20m_Id_1291.tif
# ✅ Copied: 0_id_1292.tif → Mask_Buffer20m_Id_1292.tif
# ✅ Copied: 1_id_1293.tif → Mask_Buffer20m_Id_1293.tif
# ✅ Copied: 0_id_1294.tif → Mask_Buffer20m_Id_1294.tif
# ✅ Copied: 1_id_1298.tif → Mask_Buffer20m_Id_1298.tif
# ✅ Copied: 0_id_1299.tif → Mask_Buffer20m_Id_1299.tif
# ✅ Copied: 1_id_1300.tif → Mask_Buffer20m_Id_1300.tif
# ✅ Copied: 1_id_1301.tif → Mask_Buffer20m_Id_1301.tif
# ✅ Copied: 1_id_1303.tif → Mask_Buffer20m_Id_1303.tif
# ✅ Copied: 1_id_1306.tif → Mask_Buffer20m_Id_1306.tif
# ✅ Copied: 1_id_1309.tif → Mask_Buffer20m_Id_1309.tif
# ✅ Copied: 0_id_1311.tif → Mask_Buffer20m_Id_1311.tif
# ✅ Copied: 0_id_1312.tif → Mask_Buffer20m_Id_1312.tif
# ✅ Copied: 0_id_1313.tif → Mask_Buffer20m_Id_1313.tif
# ✅ Copied: 1_id_1314.tif → Mask_Buffer20m_Id_1314.tif
# ✅ Copied: 0_id_1315.tif → Mask_Buffer20m_Id_1315.tif
# ✅ Copied: 1_id_1316.tif → Mask_Buffer20m_Id_1316.tif
# ✅ Copied: 1_id_1318.tif → Mask_Buffer20m_Id_1318.tif
# ✅ Copied: 0_id_1319.tif → Mask_Buffer20m_Id_1319.tif
# ✅ Copied: 0_id_1323.tif → Mask_Buffer20m_Id_1323.tif
# ✅ Copied: 1_id_1324.tif → Mask_Buffer20m_Id_1324.tif
# ✅ Copied: 0_id_1325.tif → Mask_Buffer20m_Id_1325.tif
# ✅ Copied: 1_id_1326.tif → Mask_Buffer20m_Id_1326.tif
# ✅ Copied: 0_id_1328.tif → Mask_Buffer20m_Id_1328.tif
# ✅ Copied: 1_id_1330.tif → Mask_Buffer20m_Id_1330.tif
# ✅ Copied: 1_id_1331.tif → Mask_Buffer20m_Id_1331.tif
# ✅ Copied: 1_id_1332.tif → Mask_Buffer20m_Id_1332.tif
# ✅ Copied: 0_id_1333.tif → Mask_Buffer20m_Id_1333.tif
# ✅ Copied: 1_id_1334.tif → Mask_Buffer20m_Id_1334.tif
# ✅ Copied: 1_id_1335.tif → Mask_Buffer20m_Id_1335.tif
# ✅ Copied: 1_id_1336.tif → Mask_Buffer20m_Id_1336.tif
# ✅ Copied: 1_id_1337.tif → Mask_Buffer20m_Id_1337.tif
# ✅ Copied: 0_id_1338.tif → Mask_Buffer20m_Id_1338.tif
# ✅ Copied: 1_id_1339.tif → Mask_Buffer20m_Id_1339.tif
# ✅ Copied: 0_id_1340.tif → Mask_Buffer20m_Id_1340.tif
# ✅ Copied: 0_id_1341.tif → Mask_Buffer20m_Id_1341.tif
# ✅ Copied: 0_id_1342.tif → Mask_Buffer20m_Id_1342.tif
# ✅ Copied: 1_id_1343.tif → Mask_Buffer20m_Id_1343.tif
# ✅ Copied: 0_id_1344.tif → Mask_Buffer20m_Id_1344.tif
# ✅ Copied: 0_id_1345.tif → Mask_Buffer20m_Id_1345.tif
# ✅ Copied: 1_id_1347.tif → Mask_Buffer20m_Id_1347.tif
# ✅ Copied: 1_id_1348.tif → Mask_Buffer20m_Id_1348.tif
# ✅ Copied: 1_id_1349.tif → Mask_Buffer20m_Id_1349.tif
# ✅ Copied: 1_id_1350.tif → Mask_Buffer20m_Id_1350.tif
# ✅ Copied: 0_id_1351.tif → Mask_Buffer20m_Id_1351.tif
# ✅ Copied: 1_id_1352.tif → Mask_Buffer20m_Id_1352.tif
# ✅ Copied: 0_id_1353.tif → Mask_Buffer20m_Id_1353.tif
# ✅ Copied: 0_id_1355.tif → Mask_Buffer20m_Id_1355.tif
# ✅ Copied: 1_id_1357.tif → Mask_Buffer20m_Id_1357.tif
# ✅ Copied: 0_id_1358.tif → Mask_Buffer20m_Id_1358.tif
# ✅ Copied: 0_id_1359.tif → Mask_Buffer20m_Id_1359.tif
# ✅ Copied: 0_id_1360.tif → Mask_Buffer20m_Id_1360.tif
# ✅ Copied: 1_id_1361.tif → Mask_Buffer20m_Id_1361.tif
# ✅ Copied: 0_id_1363.tif → Mask_Buffer20m_Id_1363.tif
# ✅ Copied: 1_id_1364.tif → Mask_Buffer20m_Id_1364.tif
# ✅ Copied: 1_id_1366.tif → Mask_Buffer20m_Id_1366.tif
# ✅ Copied: 1_id_1368.tif → Mask_Buffer20m_Id_1368.tif
# ✅ Copied: 0_id_1369.tif → Mask_Buffer20m_Id_1369.tif
# ✅ Copied: 0_id_1370.tif → Mask_Buffer20m_Id_1370.tif
# ✅ Copied: 1_id_1371.tif → Mask_Buffer20m_Id_1371.tif
# ✅ Copied: 0_id_1372.tif → Mask_Buffer20m_Id_1372.tif
# ✅ Copied: 1_id_1373.tif → Mask_Buffer20m_Id_1373.tif
# ✅ Copied: 0_id_1374.tif → Mask_Buffer20m_Id_1374.tif
# ✅ Copied: 1_id_1375.tif → Mask_Buffer20m_Id_1375.tif
# ✅ Copied: 1_id_1376.tif → Mask_Buffer20m_Id_1376.tif
# ✅ Copied: 1_id_1378.tif → Mask_Buffer20m_Id_1378.tif
# ✅ Copied: 1_id_1380.tif → Mask_Buffer20m_Id_1380.tif
# ✅ Copied: 0_id_1381.tif → Mask_Buffer20m_Id_1381.tif
# ✅ Copied: 1_id_1382.tif → Mask_Buffer20m_Id_1382.tif
# ✅ Copied: 1_id_1383.tif → Mask_Buffer20m_Id_1383.tif
# ✅ Copied: 1_id_1384.tif → Mask_Buffer20m_Id_1384.tif
# ✅ Copied: 0_id_1385.tif → Mask_Buffer20m_Id_1385.tif
# ✅ Copied: 0_id_1386.tif → Mask_Buffer20m_Id_1386.tif
# ✅ Copied: 0_id_1387.tif → Mask_Buffer20m_Id_1387.tif
# ✅ Copied: 0_id_1389.tif → Mask_Buffer20m_Id_1389.tif
# ✅ Copied: 1_id_1392.tif → Mask_Buffer20m_Id_1392.tif
# ✅ Copied: 0_id_1396.tif → Mask_Buffer20m_Id_1396.tif
# ✅ Copied: 1_id_1397.tif → Mask_Buffer20m_Id_1397.tif
# ✅ Copied: 1_id_1399.tif → Mask_Buffer20m_Id_1399.tif
# ✅ Copied: 1_id_1400.tif → Mask_Buffer20m_Id_1400.tif
# ✅ Copied: 1_id_1401.tif → Mask_Buffer20m_Id_1401.tif
# ✅ Copied: 1_id_1402.tif → Mask_Buffer20m_Id_1402.tif
# ✅ Copied: 0_id_1403.tif → Mask_Buffer20m_Id_1403.tif
# ✅ Copied: 0_id_1404.tif → Mask_Buffer20m_Id_1404.tif
# ✅ Copied: 0_id_1405.tif → Mask_Buffer20m_Id_1405.tif
# ✅ Copied: 1_id_1406.tif → Mask_Buffer20m_Id_1406.tif
# ✅ Copied: 0_id_1407.tif → Mask_Buffer20m_Id_1407.tif
# ✅ Copied: 0_id_1408.tif → Mask_Buffer20m_Id_1408.tif
# ✅ Copied: 1_id_1409.tif → Mask_Buffer20m_Id_1409.tif
# ✅ Copied: 1_id_1410.tif → Mask_Buffer20m_Id_1410.tif
# ✅ Copied: 0_id_1411.tif → Mask_Buffer20m_Id_1411.tif
# ✅ Copied: 1_id_1412.tif → Mask_Buffer20m_Id_1412.tif
# ✅ Copied: 0_id_1413.tif → Mask_Buffer20m_Id_1413.tif
# ✅ Copied: 0_id_1414.tif → Mask_Buffer20m_Id_1414.tif
# ✅ Copied: 0_id_1415.tif → Mask_Buffer20m_Id_1415.tif
# ✅ Copied: 1_id_1416.tif → Mask_Buffer20m_Id_1416.tif
# ✅ Copied: 1_id_1417.tif → Mask_Buffer20m_Id_1417.tif
# ✅ Copied: 1_id_1418.tif → Mask_Buffer20m_Id_1418.tif
# ✅ Copied: 1_id_1419.tif → Mask_Buffer20m_Id_1419.tif
# ✅ Copied: 0_id_1420.tif → Mask_Buffer20m_Id_1420.tif
# ✅ Copied: 0_id_1421.tif → Mask_Buffer20m_Id_1421.tif
# ✅ Copied: 0_id_1423.tif → Mask_Buffer20m_Id_1423.tif
# ✅ Copied: 1_id_1424.tif → Mask_Buffer20m_Id_1424.tif
# ✅ Copied: 0_id_1427.tif → Mask_Buffer20m_Id_1427.tif
# ✅ Copied: 1_id_1428.tif → Mask_Buffer20m_Id_1428.tif
# ✅ Copied: 1_id_1429.tif → Mask_Buffer20m_Id_1429.tif
# ✅ Copied: 1_id_1430.tif → Mask_Buffer20m_Id_1430.tif
# ✅ Copied: 0_id_1431.tif → Mask_Buffer20m_Id_1431.tif
# ✅ Copied: 0_id_1432.tif → Mask_Buffer20m_Id_1432.tif
# ✅ Copied: 0_id_1433.tif → Mask_Buffer20m_Id_1433.tif
# ✅ Copied: 1_id_1434.tif → Mask_Buffer20m_Id_1434.tif
# ✅ Copied: 0_id_1435.tif → Mask_Buffer20m_Id_1435.tif
# ✅ Copied: 1_id_1436.tif → Mask_Buffer20m_Id_1436.tif
# ✅ Copied: 0_id_1437.tif → Mask_Buffer20m_Id_1437.tif
# ✅ Copied: 0_id_1438.tif → Mask_Buffer20m_Id_1438.tif
# ✅ Copied: 0_id_1439.tif → Mask_Buffer20m_Id_1439.tif
# ✅ Copied: 0_id_1440.tif → Mask_Buffer20m_Id_1440.tif
# ✅ Copied: 1_id_1441.tif → Mask_Buffer20m_Id_1441.tif
# ✅ Copied: 1_id_1442.tif → Mask_Buffer20m_Id_1442.tif
# ✅ Copied: 1_id_1444.tif → Mask_Buffer20m_Id_1444.tif
# ✅ Copied: 1_id_1445.tif → Mask_Buffer20m_Id_1445.tif
# ✅ Copied: 1_id_1446.tif → Mask_Buffer20m_Id_1446.tif
# ✅ Copied: 1_id_1447.tif → Mask_Buffer20m_Id_1447.tif
# ✅ Copied: 1_id_1448.tif → Mask_Buffer20m_Id_1448.tif
# ✅ Copied: 1_id_1449.tif → Mask_Buffer20m_Id_1449.tif
# ✅ Copied: 1_id_1450.tif → Mask_Buffer20m_Id_1450.tif
# ✅ Copied: 0_id_1451.tif → Mask_Buffer20m_Id_1451.tif
# ✅ Copied: 1_id_1453.tif → Mask_Buffer20m_Id_1453.tif
# ✅ Copied: 1_id_1454.tif → Mask_Buffer20m_Id_1454.tif
# ✅ Copied: 1_id_1455.tif → Mask_Buffer20m_Id_1455.tif
# ✅ Copied: 1_id_1457.tif → Mask_Buffer20m_Id_1457.tif
# ✅ Copied: 1_id_1458.tif → Mask_Buffer20m_Id_1458.tif
# ✅ Copied: 1_id_1459.tif → Mask_Buffer20m_Id_1459.tif
# ✅ Copied: 1_id_1460.tif → Mask_Buffer20m_Id_1460.tif
# ✅ Copied: 1_id_1461.tif → Mask_Buffer20m_Id_1461.tif
# ✅ Copied: 1_id_1462.tif → Mask_Buffer20m_Id_1462.tif
# ✅ Copied: 0_id_1463.tif → Mask_Buffer20m_Id_1463.tif
# ✅ Copied: 1_id_1464.tif → Mask_Buffer20m_Id_1464.tif
# ✅ Copied: 1_id_1465.tif → Mask_Buffer20m_Id_1465.tif
# ✅ Copied: 1_id_1466.tif → Mask_Buffer20m_Id_1466.tif
# ✅ Copied: 0_id_1467.tif → Mask_Buffer20m_Id_1467.tif
# ✅ Copied: 1_id_1468.tif → Mask_Buffer20m_Id_1468.tif
# ✅ Copied: 1_id_1469.tif → Mask_Buffer20m_Id_1469.tif
# ✅ Copied: 1_id_1470.tif → Mask_Buffer20m_Id_1470.tif
# ✅ Copied: 1_id_1471.tif → Mask_Buffer20m_Id_1471.tif
# ✅ Copied: 0_id_1472.tif → Mask_Buffer20m_Id_1472.tif
# ✅ Copied: 1_id_1473.tif → Mask_Buffer20m_Id_1473.tif
# ✅ Copied: 1_id_1474.tif → Mask_Buffer20m_Id_1474.tif
# ✅ Copied: 1_id_1475.tif → Mask_Buffer20m_Id_1475.tif
# ✅ Copied: 0_id_1476.tif → Mask_Buffer20m_Id_1476.tif
# ✅ Copied: 0_id_1477.tif → Mask_Buffer20m_Id_1477.tif
# ✅ Copied: 0_id_1479.tif → Mask_Buffer20m_Id_1479.tif
# ✅ Copied: 0_id_1480.tif → Mask_Buffer20m_Id_1480.tif
# ✅ Copied: 0_id_1481.tif → Mask_Buffer20m_Id_1481.tif
# ✅ Copied: 1_id_1482.tif → Mask_Buffer20m_Id_1482.tif
# ✅ Copied: 1_id_1483.tif → Mask_Buffer20m_Id_1483.tif
# ✅ Copied: 0_id_1484.tif → Mask_Buffer20m_Id_1484.tif
# ✅ Copied: 0_id_1485.tif → Mask_Buffer20m_Id_1485.tif
# ✅ Copied: 0_id_1486.tif → Mask_Buffer20m_Id_1486.tif
# ✅ Copied: 0_id_1487.tif → Mask_Buffer20m_Id_1487.tif
# ✅ Copied: 1_id_1488.tif → Mask_Buffer20m_Id_1488.tif
# ✅ Copied: 1_id_1490.tif → Mask_Buffer20m_Id_1490.tif
# ✅ Copied: 1_id_1491.tif → Mask_Buffer20m_Id_1491.tif
# ✅ Copied: 0_id_1492.tif → Mask_Buffer20m_Id_1492.tif
# ✅ Copied: 1_id_1493.tif → Mask_Buffer20m_Id_1493.tif
# ✅ Copied: 1_id_1494.tif → Mask_Buffer20m_Id_1494.tif
# ✅ Copied: 0_id_1496.tif → Mask_Buffer20m_Id_1496.tif
# ✅ Copied: 0_id_1497.tif → Mask_Buffer20m_Id_1497.tif
# ✅ Copied: 1_id_1498.tif → Mask_Buffer20m_Id_1498.tif
# ✅ Copied: 1_id_1500.tif → Mask_Buffer20m_Id_1500.tif
# ✅ Copied: 1_id_1501.tif → Mask_Buffer20m_Id_1501.tif
# ✅ Copied: 0_id_1502.tif → Mask_Buffer20m_Id_1502.tif
# ✅ Copied: 1_id_1503.tif → Mask_Buffer20m_Id_1503.tif
# ✅ Copied: 1_id_1504.tif → Mask_Buffer20m_Id_1504.tif
# ✅ Copied: 0_id_1505.tif → Mask_Buffer20m_Id_1505.tif
# ✅ Copied: 1_id_1506.tif → Mask_Buffer20m_Id_1506.tif
# ✅ Copied: 1_id_1507.tif → Mask_Buffer20m_Id_1507.tif
# ✅ Copied: 1_id_1508.tif → Mask_Buffer20m_Id_1508.tif
# ✅ Copied: 1_id_1509.tif → Mask_Buffer20m_Id_1509.tif
# ✅ Copied: 1_id_1510.tif → Mask_Buffer20m_Id_1510.tif
# ✅ Copied: 1_id_1511.tif → Mask_Buffer20m_Id_1511.tif
# ✅ Copied: 0_id_1512.tif → Mask_Buffer20m_Id_1512.tif
# ✅ Copied: 1_id_1513.tif → Mask_Buffer20m_Id_1513.tif
# ✅ Copied: 0_id_1514.tif → Mask_Buffer20m_Id_1514.tif
# ✅ Copied: 0_id_1515.tif → Mask_Buffer20m_Id_1515.tif
# ✅ Copied: 1_id_1516.tif → Mask_Buffer20m_Id_1516.tif
# ✅ Copied: 1_id_1518.tif → Mask_Buffer20m_Id_1518.tif
# ✅ Copied: 1_id_1519.tif → Mask_Buffer20m_Id_1519.tif
# ✅ Copied: 1_id_1520.tif → Mask_Buffer20m_Id_1520.tif
# ✅ Copied: 1_id_1522.tif → Mask_Buffer20m_Id_1522.tif
# ✅ Copied: 0_id_1524.tif → Mask_Buffer20m_Id_1524.tif
# ✅ Copied: 1_id_1525.tif → Mask_Buffer20m_Id_1525.tif
# ✅ Copied: 0_id_1526.tif → Mask_Buffer20m_Id_1526.tif
# ✅ Copied: 1_id_1527.tif → Mask_Buffer20m_Id_1527.tif
# ✅ Copied: 0_id_1528.tif → Mask_Buffer20m_Id_1528.tif
# ✅ Copied: 1_id_1529.tif → Mask_Buffer20m_Id_1529.tif
# ✅ Copied: 0_id_1530.tif → Mask_Buffer20m_Id_1530.tif
# ✅ Copied: 0_id_1531.tif → Mask_Buffer20m_Id_1531.tif
# ✅ Copied: 0_id_1532.tif → Mask_Buffer20m_Id_1532.tif
# ✅ Copied: 0_id_1533.tif → Mask_Buffer20m_Id_1533.tif
# ✅ Copied: 1_id_1535.tif → Mask_Buffer20m_Id_1535.tif
# ✅ Copied: 0_id_1537.tif → Mask_Buffer20m_Id_1537.tif
# ✅ Copied: 1_id_1538.tif → Mask_Buffer20m_Id_1538.tif
# ✅ Copied: 0_id_1539.tif → Mask_Buffer20m_Id_1539.tif
# ✅ Copied: 0_id_1540.tif → Mask_Buffer20m_Id_1540.tif
# ✅ Copied: 0_id_1541.tif → Mask_Buffer20m_Id_1541.tif
# ✅ Copied: 0_id_1542.tif → Mask_Buffer20m_Id_1542.tif
# ✅ Copied: 1_id_1543.tif → Mask_Buffer20m_Id_1543.tif
# ✅ Copied: 0_id_1544.tif → Mask_Buffer20m_Id_1544.tif
# ✅ Copied: 0_id_1587.tif → Mask_Buffer20m_Id_1587.tif
# ✅ Copied: 0_id_1588.tif → Mask_Buffer20m_Id_1588.tif
# ✅ Copied: 1_id_1589.tif → Mask_Buffer20m_Id_1589.tif
# ✅ Copied: 1_id_1590.tif → Mask_Buffer20m_Id_1590.tif
# ✅ Copied: 1_id_1591.tif → Mask_Buffer20m_Id_1591.tif
# ✅ Copied: 1_id_1592.tif → Mask_Buffer20m_Id_1592.tif
# ✅ Copied: 0_id_1593.tif → Mask_Buffer20m_Id_1593.tif
# ✅ Copied: 0_id_1594.tif → Mask_Buffer20m_Id_1594.tif
# ✅ Copied: 0_id_1595.tif → Mask_Buffer20m_Id_1595.tif
# ✅ Copied: 0_id_1596.tif → Mask_Buffer20m_Id_1596.tif
# ✅ Copied: 0_id_1597.tif → Mask_Buffer20m_Id_1597.tif
# ✅ Copied: 0_id_1598.tif → Mask_Buffer20m_Id_1598.tif
# ✅ Copied: 1_id_1599.tif → Mask_Buffer20m_Id_1599.tif
# ✅ Copied: 0_id_1600.tif → Mask_Buffer20m_Id_1600.tif
# ✅ Copied: 1_id_1601.tif → Mask_Buffer20m_Id_1601.tif
# ✅ Copied: 1_id_1602.tif → Mask_Buffer20m_Id_1602.tif
# ✅ Copied: 1_id_1603.tif → Mask_Buffer20m_Id_1603.tif
# ✅ Copied: 0_id_1604.tif → Mask_Buffer20m_Id_1604.tif
# ✅ Copied: 0_id_1605.tif → Mask_Buffer20m_Id_1605.tif
# ✅ Copied: 1_id_1606.tif → Mask_Buffer20m_Id_1606.tif
# ✅ Copied: 0_id_1607.tif → Mask_Buffer20m_Id_1607.tif
# ✅ Copied: 0_id_1608.tif → Mask_Buffer20m_Id_1608.tif
# ✅ Copied: 0_id_1609.tif → Mask_Buffer20m_Id_1609.tif
# ✅ Copied: 0_id_1610.tif → Mask_Buffer20m_Id_1610.tif
# ✅ Copied: 1_id_1611.tif → Mask_Buffer20m_Id_1611.tif
# ✅ Copied: 0_id_1615.tif → Mask_Buffer20m_Id_1615.tif
# ✅ Copied: 0_id_1616.tif → Mask_Buffer20m_Id_1616.tif
# ✅ Copied: 0_id_1617.tif → Mask_Buffer20m_Id_1617.tif
# ✅ Copied: 0_id_1618.tif → Mask_Buffer20m_Id_1618.tif
# ✅ Copied: 0_id_1619.tif → Mask_Buffer20m_Id_1619.tif
# ✅ Copied: 0_id_1620.tif → Mask_Buffer20m_Id_1620.tif
# ✅ Copied: 0_id_1621.tif → Mask_Buffer20m_Id_1621.tif
# ✅ Copied: 0_id_1622.tif → Mask_Buffer20m_Id_1622.tif
# ✅ Copied: 0_id_1623.tif → Mask_Buffer20m_Id_1623.tif
# ✅ Copied: 0_id_1624.tif → Mask_Buffer20m_Id_1624.tif
# ✅ Copied: 1_id_1625.tif → Mask_Buffer20m_Id_1625.tif
# ✅ Copied: 1_id_1626.tif → Mask_Buffer20m_Id_1626.tif
# ✅ Copied: 1_id_1627.tif → Mask_Buffer20m_Id_1627.tif
# ✅ Copied: 0_id_1628.tif → Mask_Buffer20m_Id_1628.tif
# ✅ Copied: 1_id_1629.tif → Mask_Buffer20m_Id_1629.tif
# ✅ Copied: 0_id_1630.tif → Mask_Buffer20m_Id_1630.tif
# ✅ Copied: 0_id_1631.tif → Mask_Buffer20m_Id_1631.tif
# ✅ Copied: 0_id_1634.tif → Mask_Buffer20m_Id_1634.tif
# ✅ Copied: 0_id_1635.tif → Mask_Buffer20m_Id_1635.tif
# ✅ Copied: 0_id_1636.tif → Mask_Buffer20m_Id_1636.tif
# ✅ Copied: 0_id_1637.tif → Mask_Buffer20m_Id_1637.tif
# ✅ Copied: 0_id_1638.tif → Mask_Buffer20m_Id_1638.tif
# ✅ Copied: 0_id_1639.tif → Mask_Buffer20m_Id_1639.tif
# ✅ Copied: 0_id_1640.tif → Mask_Buffer20m_Id_1640.tif
# ✅ Copied: 0_id_1641.tif → Mask_Buffer20m_Id_1641.tif
# ✅ Copied: 0_id_1642.tif → Mask_Buffer20m_Id_1642.tif
# ✅ Copied: 0_id_1643.tif → Mask_Buffer20m_Id_1643.tif
# ✅ Copied: 0_id_1644.tif → Mask_Buffer20m_Id_1644.tif
# ✅ Copied: 0_id_1645.tif → Mask_Buffer20m_Id_1645.tif
# ✅ Copied: 1_id_1646.tif → Mask_Buffer20m_Id_1646.tif
# ✅ Copied: 1_id_1647.tif → Mask_Buffer20m_Id_1647.tif
# ✅ Copied: 0_id_1649.tif → Mask_Buffer20m_Id_1649.tif
# ✅ Copied: 1_id_1650.tif → Mask_Buffer20m_Id_1650.tif
# ✅ Copied: 1_id_1000.tif → Mask_Buffer20m_Id_1000.tif
# ✅ Copied: 1_id_1001.tif → Mask_Buffer20m_Id_1001.tif
# ✅ Copied: 1_id_1002.tif → Mask_Buffer20m_Id_1002.tif
# ✅ Copied: 1_id_1003.tif → Mask_Buffer20m_Id_1003.tif
# ✅ Copied: 1_id_1005.tif → Mask_Buffer20m_Id_1005.tif
# ✅ Copied: 1_id_1006.tif → Mask_Buffer20m_Id_1006.tif
# ✅ Copied: 1_id_1008.tif → Mask_Buffer20m_Id_1008.tif
# ✅ Copied: 1_id_1009.tif → Mask_Buffer20m_Id_1009.tif
# ✅ Copied: 1_id_1011.tif → Mask_Buffer20m_Id_1011.tif
# ✅ Copied: 1_id_1012.tif → Mask_Buffer20m_Id_1012.tif
# ✅ Copied: 1_id_1013.tif → Mask_Buffer20m_Id_1013.tif
# ✅ Copied: 1_id_1014.tif → Mask_Buffer20m_Id_1014.tif
# ✅ Copied: 0_id_1017.tif → Mask_Buffer20m_Id_1017.tif
# ✅ Copied: 1_id_1018.tif → Mask_Buffer20m_Id_1018.tif
# ✅ Copied: 1_id_1020.tif → Mask_Buffer20m_Id_1020.tif
# ✅ Copied: 1_id_1022.tif → Mask_Buffer20m_Id_1022.tif
# ✅ Copied: 1_id_1023.tif → Mask_Buffer20m_Id_1023.tif
# ✅ Copied: 1_id_1024.tif → Mask_Buffer20m_Id_1024.tif
# ✅ Copied: 1_id_1025.tif → Mask_Buffer20m_Id_1025.tif
# ✅ Copied: 1_id_1028.tif → Mask_Buffer20m_Id_1028.tif
# ✅ Copied: 1_id_1029.tif → Mask_Buffer20m_Id_1029.tif
# ✅ Copied: 0_id_1030.tif → Mask_Buffer20m_Id_1030.tif
# ✅ Copied: 1_id_1031.tif → Mask_Buffer20m_Id_1031.tif
# ✅ Copied: 1_id_1032.tif → Mask_Buffer20m_Id_1032.tif
# ✅ Copied: 1_id_1033.tif → Mask_Buffer20m_Id_1033.tif
# ✅ Copied: 1_id_1034.tif → Mask_Buffer20m_Id_1034.tif
# ✅ Copied: 0_id_1035.tif → Mask_Buffer20m_Id_1035.tif
# ✅ Copied: 0_id_1036.tif → Mask_Buffer20m_Id_1036.tif
# ✅ Copied: 1_id_1037.tif → Mask_Buffer20m_Id_1037.tif
# ✅ Copied: 1_id_1039.tif → Mask_Buffer20m_Id_1039.tif
# ✅ Copied: 0_id_1040.tif → Mask_Buffer20m_Id_1040.tif
# ✅ Copied: 0_id_1042.tif → Mask_Buffer20m_Id_1042.tif
# ✅ Copied: 1_id_1046.tif → Mask_Buffer20m_Id_1046.tif
# ✅ Copied: 0_id_1047.tif → Mask_Buffer20m_Id_1047.tif
# ✅ Copied: 1_id_1049.tif → Mask_Buffer20m_Id_1049.tif
# ✅ Copied: 1_id_1050.tif → Mask_Buffer20m_Id_1050.tif
# ✅ Copied: 0_id_1051.tif → Mask_Buffer20m_Id_1051.tif
# ✅ Copied: 0_id_1052.tif → Mask_Buffer20m_Id_1052.tif
# ✅ Copied: 1_id_1053.tif → Mask_Buffer20m_Id_1053.tif
# ✅ Copied: 1_id_1054.tif → Mask_Buffer20m_Id_1054.tif
# ✅ Copied: 0_id_1056.tif → Mask_Buffer20m_Id_1056.tif
# ✅ Copied: 0_id_1057.tif → Mask_Buffer20m_Id_1057.tif
# ✅ Copied: 1_id_1058.tif → Mask_Buffer20m_Id_1058.tif
# ✅ Copied: 0_id_1059.tif → Mask_Buffer20m_Id_1059.tif
# ✅ Copied: 1_id_1060.tif → Mask_Buffer20m_Id_1060.tif
# ✅ Copied: 0_id_1061.tif → Mask_Buffer20m_Id_1061.tif
# ✅ Copied: 0_id_1062.tif → Mask_Buffer20m_Id_1062.tif
# ✅ Copied: 0_id_1063.tif → Mask_Buffer20m_Id_1063.tif
# ✅ Copied: 1_id_1064.tif → Mask_Buffer20m_Id_1064.tif
# ✅ Copied: 0_id_1065.tif → Mask_Buffer20m_Id_1065.tif
# ✅ Copied: 1_id_1066.tif → Mask_Buffer20m_Id_1066.tif
# ✅ Copied: 1_id_1067.tif → Mask_Buffer20m_Id_1067.tif
# ✅ Copied: 0_id_1070.tif → Mask_Buffer20m_Id_1070.tif
# ✅ Copied: 1_id_1072.tif → Mask_Buffer20m_Id_1072.tif
# ✅ Copied: 0_id_1073.tif → Mask_Buffer20m_Id_1073.tif
# ✅ Copied: 1_id_1074.tif → Mask_Buffer20m_Id_1074.tif
# ✅ Copied: 0_id_1075.tif → Mask_Buffer20m_Id_1075.tif
# ✅ Copied: 1_id_1076.tif → Mask_Buffer20m_Id_1076.tif
# ✅ Copied: 1_id_1077.tif → Mask_Buffer20m_Id_1077.tif
# ✅ Copied: 0_id_1078.tif → Mask_Buffer20m_Id_1078.tif
# ✅ Copied: 0_id_1079.tif → Mask_Buffer20m_Id_1079.tif
# ✅ Copied: 1_id_1080.tif → Mask_Buffer20m_Id_1080.tif
# ✅ Copied: 0_id_1081.tif → Mask_Buffer20m_Id_1081.tif
# ✅ Copied: 1_id_1082.tif → Mask_Buffer20m_Id_1082.tif
# ✅ Copied: 1_id_1084.tif → Mask_Buffer20m_Id_1084.tif
# ✅ Copied: 1_id_1085.tif → Mask_Buffer20m_Id_1085.tif
# ✅ Copied: 1_id_1086.tif → Mask_Buffer20m_Id_1086.tif
# ✅ Copied: 1_id_1087.tif → Mask_Buffer20m_Id_1087.tif
# ✅ Copied: 0_id_1088.tif → Mask_Buffer20m_Id_1088.tif
# ✅ Copied: 1_id_1089.tif → Mask_Buffer20m_Id_1089.tif
# ✅ Copied: 1_id_1090.tif → Mask_Buffer20m_Id_1090.tif
# ✅ Copied: 1_id_1091.tif → Mask_Buffer20m_Id_1091.tif
# ✅ Copied: 1_id_1092.tif → Mask_Buffer20m_Id_1092.tif
# ✅ Copied: 0_id_1093.tif → Mask_Buffer20m_Id_1093.tif
# ✅ Copied: 1_id_1094.tif → Mask_Buffer20m_Id_1094.tif
# ✅ Copied: 1_id_1095.tif → Mask_Buffer20m_Id_1095.tif
# ✅ Copied: 1_id_1096.tif → Mask_Buffer20m_Id_1096.tif
# ✅ Copied: 0_id_1097.tif → Mask_Buffer20m_Id_1097.tif
# ✅ Copied: 1_id_1098.tif → Mask_Buffer20m_Id_1098.tif
# ✅ Copied: 1_id_1099.tif → Mask_Buffer20m_Id_1099.tif
# ✅ Copied: 0_id_1100.tif → Mask_Buffer20m_Id_1100.tif
# ✅ Copied: 0_id_1101.tif → Mask_Buffer20m_Id_1101.tif
# ✅ Copied: 1_id_1103.tif → Mask_Buffer20m_Id_1103.tif
# ✅ Copied: 0_id_1104.tif → Mask_Buffer20m_Id_1104.tif
# ✅ Copied: 1_id_1105.tif → Mask_Buffer20m_Id_1105.tif
# ✅ Copied: 1_id_1106.tif → Mask_Buffer20m_Id_1106.tif
# ✅ Copied: 1_id_1107.tif → Mask_Buffer20m_Id_1107.tif
# ✅ Copied: 0_id_1108.tif → Mask_Buffer20m_Id_1108.tif
# ✅ Copied: 0_id_1109.tif → Mask_Buffer20m_Id_1109.tif
# ✅ Copied: 1_id_1109.tif → Mask_Buffer20m_Id_1109.tif
# ✅ Copied: 1_id_1111.tif → Mask_Buffer20m_Id_1111.tif
# ✅ Copied: 0_id_1112.tif → Mask_Buffer20m_Id_1112.tif
# ✅ Copied: 1_id_1113.tif → Mask_Buffer20m_Id_1113.tif
# ✅ Copied: 1_id_1114.tif → Mask_Buffer20m_Id_1114.tif
# ✅ Copied: 1_id_1115.tif → Mask_Buffer20m_Id_1115.tif
# ✅ Copied: 1_id_1116.tif → Mask_Buffer20m_Id_1116.tif
# ✅ Copied: 1_id_1117.tif → Mask_Buffer20m_Id_1117.tif
# ✅ Copied: 1_id_1118.tif → Mask_Buffer20m_Id_1118.tif
# ✅ Copied: 1_id_1119.tif → Mask_Buffer20m_Id_1119.tif
# ✅ Copied: 0_id_1120.tif → Mask_Buffer20m_Id_1120.tif
# ✅ Copied: 1_id_1122.tif → Mask_Buffer20m_Id_1122.tif
# ✅ Copied: 1_id_1123.tif → Mask_Buffer20m_Id_1123.tif
# ✅ Copied: 1_id_1124.tif → Mask_Buffer20m_Id_1124.tif
# ✅ Copied: 1_id_1126.tif → Mask_Buffer20m_Id_1126.tif
# ✅ Copied: 0_id_1127.tif → Mask_Buffer20m_Id_1127.tif
# ✅ Copied: 0_id_1128.tif → Mask_Buffer20m_Id_1128.tif
# ✅ Copied: 1_id_1130.tif → Mask_Buffer20m_Id_1130.tif
# ✅ Copied: 1_id_1133.tif → Mask_Buffer20m_Id_1133.tif
# ✅ Copied: 0_id_1135.tif → Mask_Buffer20m_Id_1135.tif
# ✅ Copied: 1_id_1138.tif → Mask_Buffer20m_Id_1138.tif
# ✅ Copied: 1_id_1140.tif → Mask_Buffer20m_Id_1140.tif
# ✅ Copied: 1_id_1141.tif → Mask_Buffer20m_Id_1141.tif
# ✅ Copied: 1_id_1142.tif → Mask_Buffer20m_Id_1142.tif
# ✅ Copied: 1_id_1143.tif → Mask_Buffer20m_Id_1143.tif
# ✅ Copied: 1_id_1144.tif → Mask_Buffer20m_Id_1144.tif
# ✅ Copied: 1_id_1145.tif → Mask_Buffer20m_Id_1145.tif
# ✅ Copied: 0_id_1146.tif → Mask_Buffer20m_Id_1146.tif
# ✅ Copied: 1_id_1147.tif → Mask_Buffer20m_Id_1147.tif
# ✅ Copied: 1_id_1148.tif → Mask_Buffer20m_Id_1148.tif
# ✅ Copied: 1_id_1149.tif → Mask_Buffer20m_Id_1149.tif
# ✅ Copied: 1_id_1150.tif → Mask_Buffer20m_Id_1150.tif
# ✅ Copied: 0_id_1151.tif → Mask_Buffer20m_Id_1151.tif
# ✅ Copied: 1_id_1152.tif → Mask_Buffer20m_Id_1152.tif
# ✅ Copied: 1_id_1154.tif → Mask_Buffer20m_Id_1154.tif
# ✅ Copied: 1_id_1155.tif → Mask_Buffer20m_Id_1155.tif
# ✅ Copied: 1_id_1157.tif → Mask_Buffer20m_Id_1157.tif
# ✅ Copied: 1_id_1158.tif → Mask_Buffer20m_Id_1158.tif
# ✅ Copied: 0_id_1159.tif → Mask_Buffer20m_Id_1159.tif
# ✅ Copied: 1_id_1160.tif → Mask_Buffer20m_Id_1160.tif
# ✅ Copied: 1_id_1161.tif → Mask_Buffer20m_Id_1161.tif
# ✅ Copied: 1_id_1162.tif → Mask_Buffer20m_Id_1162.tif
# ✅ Copied: 1_id_1163.tif → Mask_Buffer20m_Id_1163.tif
# ✅ Copied: 0_id_1164.tif → Mask_Buffer20m_Id_1164.tif
# ✅ Copied: 1_id_1165.tif → Mask_Buffer20m_Id_1165.tif
# ✅ Copied: 1_id_1166.tif → Mask_Buffer20m_Id_1166.tif
# ✅ Copied: 1_id_1167.tif → Mask_Buffer20m_Id_1167.tif
# ✅ Copied: 1_id_1168.tif → Mask_Buffer20m_Id_1168.tif
# ✅ Copied: 1_id_1169.tif → Mask_Buffer20m_Id_1169.tif
# ✅ Copied: 0_id_1170.tif → Mask_Buffer20m_Id_1170.tif
# ✅ Copied: 1_id_1171.tif → Mask_Buffer20m_Id_1171.tif
# ✅ Copied: 0_id_1172.tif → Mask_Buffer20m_Id_1172.tif
# ✅ Copied: 1_id_1173.tif → Mask_Buffer20m_Id_1173.tif
# ✅ Copied: 1_id_1174.tif → Mask_Buffer20m_Id_1174.tif
# ✅ Copied: 1_id_1176.tif → Mask_Buffer20m_Id_1176.tif
# ✅ Copied: 1_id_1177.tif → Mask_Buffer20m_Id_1177.tif
# ✅ Copied: 1_id_1178.tif → Mask_Buffer20m_Id_1178.tif
# ✅ Copied: 1_id_1179.tif → Mask_Buffer20m_Id_1179.tif
# ✅ Copied: 1_id_1180.tif → Mask_Buffer20m_Id_1180.tif
# ✅ Copied: 1_id_1181.tif → Mask_Buffer20m_Id_1181.tif
# ✅ Copied: 0_id_1182.tif → Mask_Buffer20m_Id_1182.tif
# ✅ Copied: 1_id_1183.tif → Mask_Buffer20m_Id_1183.tif
# ✅ Copied: 1_id_1185.tif → Mask_Buffer20m_Id_1185.tif
# ✅ Copied: 1_id_1187.tif → Mask_Buffer20m_Id_1187.tif
# ✅ Copied: 1_id_1188.tif → Mask_Buffer20m_Id_1188.tif
# ✅ Copied: 1_id_1191.tif → Mask_Buffer20m_Id_1191.tif
# ✅ Copied: 1_id_1192.tif → Mask_Buffer20m_Id_1192.tif
# ✅ Copied: 1_id_1193.tif → Mask_Buffer20m_Id_1193.tif
# ✅ Copied: 1_id_1194.tif → Mask_Buffer20m_Id_1194.tif
# ✅ Copied: 1_id_1196.tif → Mask_Buffer20m_Id_1196.tif
# ✅ Copied: 1_id_1197.tif → Mask_Buffer20m_Id_1197.tif
# ✅ Copied: 1_id_1198.tif → Mask_Buffer20m_Id_1198.tif
# ✅ Copied: 1_id_1200.tif → Mask_Buffer20m_Id_1200.tif
# ✅ Copied: 1_id_1201.tif → Mask_Buffer20m_Id_1201.tif
# ✅ Copied: 0_id_1202.tif → Mask_Buffer20m_Id_1202.tif
# ✅ Copied: 1_id_1203.tif → Mask_Buffer20m_Id_1203.tif
# ✅ Copied: 1_id_1204.tif → Mask_Buffer20m_Id_1204.tif
# ✅ Copied: 0_id_1205.tif → Mask_Buffer20m_Id_1205.tif
# ✅ Copied: 1_id_1206.tif → Mask_Buffer20m_Id_1206.tif
# ✅ Copied: 1_id_1207.tif → Mask_Buffer20m_Id_1207.tif
# ✅ Copied: 1_id_1208.tif → Mask_Buffer20m_Id_1208.tif
# ✅ Copied: 0_id_1209.tif → Mask_Buffer20m_Id_1209.tif
# ✅ Copied: 0_id_800.tif → Mask_Buffer20m_Id_800.tif
# ✅ Copied: 1_id_801.tif → Mask_Buffer20m_Id_801.tif
# ✅ Copied: 1_id_802.tif → Mask_Buffer20m_Id_802.tif
# ✅ Copied: 1_id_803.tif → Mask_Buffer20m_Id_803.tif
# ✅ Copied: 1_id_804.tif → Mask_Buffer20m_Id_804.tif
# ✅ Copied: 0_id_806.tif → Mask_Buffer20m_Id_806.tif
# ✅ Copied: 0_id_807.tif → Mask_Buffer20m_Id_807.tif
# ✅ Copied: 0_id_808.tif → Mask_Buffer20m_Id_808.tif
# ✅ Copied: 1_id_809.tif → Mask_Buffer20m_Id_809.tif
# ✅ Copied: 0_id_810.tif → Mask_Buffer20m_Id_810.tif
# ✅ Copied: 1_id_811.tif → Mask_Buffer20m_Id_811.tif
# ✅ Copied: 0_id_812.tif → Mask_Buffer20m_Id_812.tif
# ✅ Copied: 1_id_813.tif → Mask_Buffer20m_Id_813.tif
# ✅ Copied: 1_id_814.tif → Mask_Buffer20m_Id_814.tif
# ✅ Copied: 1_id_815.tif → Mask_Buffer20m_Id_815.tif
# ✅ Copied: 1_id_816.tif → Mask_Buffer20m_Id_816.tif
# ✅ Copied: 1_id_818.tif → Mask_Buffer20m_Id_818.tif
# ✅ Copied: 1_id_820.tif → Mask_Buffer20m_Id_820.tif
# ✅ Copied: 1_id_821.tif → Mask_Buffer20m_Id_821.tif
# ✅ Copied: 0_id_822.tif → Mask_Buffer20m_Id_822.tif
# ✅ Copied: 1_id_823.tif → Mask_Buffer20m_Id_823.tif
# ✅ Copied: 1_id_824.tif → Mask_Buffer20m_Id_824.tif
# ✅ Copied: 1_id_825.tif → Mask_Buffer20m_Id_825.tif
# ✅ Copied: 1_id_826.tif → Mask_Buffer20m_Id_826.tif
# ✅ Copied: 1_id_827.tif → Mask_Buffer20m_Id_827.tif
# ✅ Copied: 1_id_828.tif → Mask_Buffer20m_Id_828.tif
# ✅ Copied: 0_id_829.tif → Mask_Buffer20m_Id_829.tif
# ✅ Copied: 1_id_830.tif → Mask_Buffer20m_Id_830.tif
# ✅ Copied: 0_id_831.tif → Mask_Buffer20m_Id_831.tif
# ✅ Copied: 1_id_832.tif → Mask_Buffer20m_Id_832.tif
# ✅ Copied: 1_id_833.tif → Mask_Buffer20m_Id_833.tif
# ✅ Copied: 1_id_834.tif → Mask_Buffer20m_Id_834.tif
# ✅ Copied: 0_id_835.tif → Mask_Buffer20m_Id_835.tif
# ✅ Copied: 1_id_836.tif → Mask_Buffer20m_Id_836.tif
# ✅ Copied: 1_id_837.tif → Mask_Buffer20m_Id_837.tif
# ✅ Copied: 1_id_838.tif → Mask_Buffer20m_Id_838.tif
# ✅ Copied: 1_id_839.tif → Mask_Buffer20m_Id_839.tif
# ✅ Copied: 0_id_840.tif → Mask_Buffer20m_Id_840.tif
# ✅ Copied: 1_id_842.tif → Mask_Buffer20m_Id_842.tif
# ✅ Copied: 1_id_843.tif → Mask_Buffer20m_Id_843.tif
# ✅ Copied: 1_id_844.tif → Mask_Buffer20m_Id_844.tif
# ✅ Copied: 1_id_845.tif → Mask_Buffer20m_Id_845.tif
# ✅ Copied: 1_id_846.tif → Mask_Buffer20m_Id_846.tif
# ✅ Copied: 1_id_847.tif → Mask_Buffer20m_Id_847.tif
# ✅ Copied: 1_id_848.tif → Mask_Buffer20m_Id_848.tif
# ✅ Copied: 1_id_849.tif → Mask_Buffer20m_Id_849.tif
# ✅ Copied: 1_id_850.tif → Mask_Buffer20m_Id_850.tif
# ✅ Copied: 1_id_851.tif → Mask_Buffer20m_Id_851.tif
# ✅ Copied: 1_id_852.tif → Mask_Buffer20m_Id_852.tif
# ✅ Copied: 0_id_853.tif → Mask_Buffer20m_Id_853.tif
# ✅ Copied: 1_id_854.tif → Mask_Buffer20m_Id_854.tif
# ✅ Copied: 1_id_855.tif → Mask_Buffer20m_Id_855.tif
# ✅ Copied: 1_id_856.tif → Mask_Buffer20m_Id_856.tif
# ✅ Copied: 1_id_857.tif → Mask_Buffer20m_Id_857.tif
# ✅ Copied: 0_id_858.tif → Mask_Buffer20m_Id_858.tif
# ✅ Copied: 1_id_859.tif → Mask_Buffer20m_Id_859.tif
# ✅ Copied: 1_id_860.tif → Mask_Buffer20m_Id_860.tif
# ✅ Copied: 1_id_862.tif → Mask_Buffer20m_Id_862.tif
# ✅ Copied: 0_id_862.tif → Mask_Buffer20m_Id_862.tif
# ✅ Copied: 0_id_863.tif → Mask_Buffer20m_Id_863.tif
# ✅ Copied: 1_id_864.tif → Mask_Buffer20m_Id_864.tif
# ✅ Copied: 1_id_869.tif → Mask_Buffer20m_Id_869.tif
# ✅ Copied: 1_id_871.tif → Mask_Buffer20m_Id_871.tif
# ✅ Copied: 1_id_872.tif → Mask_Buffer20m_Id_872.tif
# ✅ Copied: 1_id_873.tif → Mask_Buffer20m_Id_873.tif
# ✅ Copied: 0_id_874.tif → Mask_Buffer20m_Id_874.tif
# ✅ Copied: 1_id_875.tif → Mask_Buffer20m_Id_875.tif
# ✅ Copied: 1_id_876.tif → Mask_Buffer20m_Id_876.tif
# ✅ Copied: 1_id_877.tif → Mask_Buffer20m_Id_877.tif
# ✅ Copied: 1_id_878.tif → Mask_Buffer20m_Id_878.tif
# ✅ Copied: 1_id_879.tif → Mask_Buffer20m_Id_879.tif
# ✅ Copied: 0_id_882.tif → Mask_Buffer20m_Id_882.tif
# ✅ Copied: 0_id_883.tif → Mask_Buffer20m_Id_883.tif
# ✅ Copied: 1_id_884.tif → Mask_Buffer20m_Id_884.tif
# ✅ Copied: 1_id_885.tif → Mask_Buffer20m_Id_885.tif
# ✅ Copied: 1_id_886.tif → Mask_Buffer20m_Id_886.tif
# ✅ Copied: 0_id_887.tif → Mask_Buffer20m_Id_887.tif
# ✅ Copied: 1_id_888.tif → Mask_Buffer20m_Id_888.tif
# ✅ Copied: 0_id_889.tif → Mask_Buffer20m_Id_889.tif
# ✅ Copied: 1_id_890.tif → Mask_Buffer20m_Id_890.tif
# ✅ Copied: 1_id_891.tif → Mask_Buffer20m_Id_891.tif
# ✅ Copied: 1_id_892.tif → Mask_Buffer20m_Id_892.tif
# ✅ Copied: 1_id_894.tif → Mask_Buffer20m_Id_894.tif
# ✅ Copied: 1_id_895.tif → Mask_Buffer20m_Id_895.tif
# ✅ Copied: 1_id_898.tif → Mask_Buffer20m_Id_898.tif
# ✅ Copied: 1_id_899.tif → Mask_Buffer20m_Id_899.tif
# ✅ Copied: 1_id_900.tif → Mask_Buffer20m_Id_900.tif
# ✅ Copied: 1_id_901.tif → Mask_Buffer20m_Id_901.tif
# ✅ Copied: 1_id_902.tif → Mask_Buffer20m_Id_902.tif
# ✅ Copied: 1_id_904.tif → Mask_Buffer20m_Id_904.tif
# ✅ Copied: 1_id_907.tif → Mask_Buffer20m_Id_907.tif
# ✅ Copied: 1_id_910.tif → Mask_Buffer20m_Id_910.tif
# ✅ Copied: 1_id_911.tif → Mask_Buffer20m_Id_911.tif
# ✅ Copied: 1_id_912.tif → Mask_Buffer20m_Id_912.tif
# ✅ Copied: 1_id_913.tif → Mask_Buffer20m_Id_913.tif
# ✅ Copied: 1_id_915.tif → Mask_Buffer20m_Id_915.tif
# ✅ Copied: 1_id_916.tif → Mask_Buffer20m_Id_916.tif
# ✅ Copied: 1_id_917.tif → Mask_Buffer20m_Id_917.tif
# ✅ Copied: 1_id_919.tif → Mask_Buffer20m_Id_919.tif
# ✅ Copied: 1_id_920.tif → Mask_Buffer20m_Id_920.tif
# ✅ Copied: 0_id_921.tif → Mask_Buffer20m_Id_921.tif
# ✅ Copied: 1_id_922.tif → Mask_Buffer20m_Id_922.tif
# ✅ Copied: 1_id_923.tif → Mask_Buffer20m_Id_923.tif
# ✅ Copied: 0_id_924.tif → Mask_Buffer20m_Id_924.tif
# ✅ Copied: 1_id_926.tif → Mask_Buffer20m_Id_926.tif
# ✅ Copied: 1_id_927.tif → Mask_Buffer20m_Id_927.tif
# ✅ Copied: 1_id_929.tif → Mask_Buffer20m_Id_929.tif
# ✅ Copied: 1_id_930.tif → Mask_Buffer20m_Id_930.tif
# ✅ Copied: 0_id_931.tif → Mask_Buffer20m_Id_931.tif
# ✅ Copied: 1_id_932.tif → Mask_Buffer20m_Id_932.tif
# ✅ Copied: 1_id_933.tif → Mask_Buffer20m_Id_933.tif
# ✅ Copied: 0_id_934.tif → Mask_Buffer20m_Id_934.tif
# ✅ Copied: 1_id_935.tif → Mask_Buffer20m_Id_935.tif
# ✅ Copied: 1_id_936.tif → Mask_Buffer20m_Id_936.tif
# ✅ Copied: 1_id_937.tif → Mask_Buffer20m_Id_937.tif
# ✅ Copied: 1_id_938.tif → Mask_Buffer20m_Id_938.tif
# ✅ Copied: 1_id_939.tif → Mask_Buffer20m_Id_939.tif
# ✅ Copied: 1_id_940.tif → Mask_Buffer20m_Id_940.tif
# ✅ Copied: 0_id_941.tif → Mask_Buffer20m_Id_941.tif
# ✅ Copied: 1_id_942.tif → Mask_Buffer20m_Id_942.tif
# ✅ Copied: 0_id_943.tif → Mask_Buffer20m_Id_943.tif
# ✅ Copied: 1_id_944.tif → Mask_Buffer20m_Id_944.tif
# ✅ Copied: 1_id_945.tif → Mask_Buffer20m_Id_945.tif
# ✅ Copied: 1_id_946.tif → Mask_Buffer20m_Id_946.tif
# ✅ Copied: 1_id_947.tif → Mask_Buffer20m_Id_947.tif
# ✅ Copied: 0_id_948.tif → Mask_Buffer20m_Id_948.tif
# ✅ Copied: 1_id_949.tif → Mask_Buffer20m_Id_949.tif
# ✅ Copied: 1_id_950.tif → Mask_Buffer20m_Id_950.tif
# ✅ Copied: 1_id_955.tif → Mask_Buffer20m_Id_955.tif
# ✅ Copied: 1_id_956.tif → Mask_Buffer20m_Id_956.tif
# ✅ Copied: 1_id_959.tif → Mask_Buffer20m_Id_959.tif
# ✅ Copied: 1_id_960.tif → Mask_Buffer20m_Id_960.tif
# ✅ Copied: 0_id_961.tif → Mask_Buffer20m_Id_961.tif
# ✅ Copied: 1_id_962.tif → Mask_Buffer20m_Id_962.tif
# ✅ Copied: 0_id_964.tif → Mask_Buffer20m_Id_964.tif
# ✅ Copied: 0_id_965.tif → Mask_Buffer20m_Id_965.tif
# ✅ Copied: 1_id_966.tif → Mask_Buffer20m_Id_966.tif
# ✅ Copied: 1_id_967.tif → Mask_Buffer20m_Id_967.tif
# ✅ Copied: 1_id_968.tif → Mask_Buffer20m_Id_968.tif
# ✅ Copied: 1_id_969.tif → Mask_Buffer20m_Id_969.tif
# ✅ Copied: 1_id_971.tif → Mask_Buffer20m_Id_971.tif
# ✅ Copied: 1_id_972.tif → Mask_Buffer20m_Id_972.tif
# ✅ Copied: 1_id_973.tif → Mask_Buffer20m_Id_973.tif
# ✅ Copied: 1_id_976.tif → Mask_Buffer20m_Id_976.tif
# ✅ Copied: 1_id_978.tif → Mask_Buffer20m_Id_978.tif
# ✅ Copied: 1_id_979.tif → Mask_Buffer20m_Id_979.tif
# ✅ Copied: 1_id_981.tif → Mask_Buffer20m_Id_981.tif
# ✅ Copied: 0_id_983.tif → Mask_Buffer20m_Id_983.tif
# ✅ Copied: 1_id_984.tif → Mask_Buffer20m_Id_984.tif
# ✅ Copied: 0_id_985.tif → Mask_Buffer20m_Id_985.tif
# ✅ Copied: 1_id_987.tif → Mask_Buffer20m_Id_987.tif
# ✅ Copied: 0_id_988.tif → Mask_Buffer20m_Id_988.tif
# ✅ Copied: 1_id_989.tif → Mask_Buffer20m_Id_989.tif
# ✅ Copied: 0_id_990.tif → Mask_Buffer20m_Id_990.tif
# ✅ Copied: 0_id_991.tif → Mask_Buffer20m_Id_991.tif
# ✅ Copied: 1_id_992.tif → Mask_Buffer20m_Id_992.tif
# ✅ Copied: 1_id_993.tif → Mask_Buffer20m_Id_993.tif
# ✅ Copied: 1_id_994.tif → Mask_Buffer20m_Id_994.tif
# ✅ Copied: 1_id_995.tif → Mask_Buffer20m_Id_995.tif
# ✅ Copied: 1_id_996.tif → Mask_Buffer20m_Id_996.tif
# ✅ Copied: 1_id_998.tif → Mask_Buffer20m_Id_998.tif
# ✅ Copied: 1_id_999.tif → Mask_Buffer20m_Id_999.tif
# ✅ Copied: 1_id_1210.tif → Mask_Buffer20m_Id_1210.tif
# 🎉 Done copying and renaming mask files.

# %%
#  Set your source and destination folders
source_folder = "/content/drive/MyDrive/Masks 800-1650"
destination_folder = "/content/drive/MyDrive/training_masks"

#  Create destination folder if it doesn't exist
os.makedirs(destination_folder, exist_ok=True)

#  Move all .tif files
for filename in os.listdir(source_folder):
    if filename.lower().endswith(".tif"):
        src_path = os.path.join(source_folder, filename)
        dst_path = os.path.join(destination_folder, filename)

        shutil.move(src_path, dst_path)
        print(f"🚚 Moved: {filename}")

print("✅ All .tif files moved and deleted from source.")
# Out:
# 🚚 Moved: Mask_Buffer20m_Id_1211.tif
# 🚚 Moved: Mask_Buffer20m_Id_1216.tif
# 🚚 Moved: Mask_Buffer20m_Id_1217.tif
# 🚚 Moved: Mask_Buffer20m_Id_1219.tif
# 🚚 Moved: Mask_Buffer20m_Id_1222.tif
# 🚚 Moved: Mask_Buffer20m_Id_1224.tif
# 🚚 Moved: Mask_Buffer20m_Id_1226.tif
# 🚚 Moved: Mask_Buffer20m_Id_1227.tif
# 🚚 Moved: Mask_Buffer20m_Id_1228.tif
# 🚚 Moved: Mask_Buffer20m_Id_1229.tif
# 🚚 Moved: Mask_Buffer20m_Id_1231.tif
# 🚚 Moved: Mask_Buffer20m_Id_1232.tif
# 🚚 Moved: Mask_Buffer20m_Id_1233.tif
# 🚚 Moved: Mask_Buffer20m_Id_1234.tif
# 🚚 Moved: Mask_Buffer20m_Id_1236.tif
# 🚚 Moved: Mask_Buffer20m_Id_1237.tif
# 🚚 Moved: Mask_Buffer20m_Id_1239.tif
# 🚚 Moved: Mask_Buffer20m_Id_1240.tif
# 🚚 Moved: Mask_Buffer20m_Id_1241.tif
# 🚚 Moved: Mask_Buffer20m_Id_1242.tif
# 🚚 Moved: Mask_Buffer20m_Id_1244.tif
# 🚚 Moved: Mask_Buffer20m_Id_1245.tif
# 🚚 Moved: Mask_Buffer20m_Id_1248.tif
# 🚚 Moved: Mask_Buffer20m_Id_1252.tif
# 🚚 Moved: Mask_Buffer20m_Id_1254.tif
# 🚚 Moved: Mask_Buffer20m_Id_1255.tif
# 🚚 Moved: Mask_Buffer20m_Id_1256.tif
# 🚚 Moved: Mask_Buffer20m_Id_1258.tif
# 🚚 Moved: Mask_Buffer20m_Id_1260.tif
# 🚚 Moved: Mask_Buffer20m_Id_1261.tif
# 🚚 Moved: Mask_Buffer20m_Id_1262.tif
# 🚚 Moved: Mask_Buffer20m_Id_1263.tif
# 🚚 Moved: Mask_Buffer20m_Id_1265.tif
# 🚚 Moved: Mask_Buffer20m_Id_1266.tif
# 🚚 Moved: Mask_Buffer20m_Id_1267.tif
# 🚚 Moved: Mask_Buffer20m_Id_1268.tif
# 🚚 Moved: Mask_Buffer20m_Id_1270.tif
# 🚚 Moved: Mask_Buffer20m_Id_1271.tif
# 🚚 Moved: Mask_Buffer20m_Id_1272.tif
# 🚚 Moved: Mask_Buffer20m_Id_1273.tif
# 🚚 Moved: Mask_Buffer20m_Id_1275.tif
# 🚚 Moved: Mask_Buffer20m_Id_1277.tif
# 🚚 Moved: Mask_Buffer20m_Id_1278.tif
# 🚚 Moved: Mask_Buffer20m_Id_1279.tif
# 🚚 Moved: Mask_Buffer20m_Id_1281.tif
# 🚚 Moved: Mask_Buffer20m_Id_1282.tif
# 🚚 Moved: Mask_Buffer20m_Id_1283.tif
# 🚚 Moved: Mask_Buffer20m_Id_1284.tif
# 🚚 Moved: Mask_Buffer20m_Id_1286.tif
# 🚚 Moved: Mask_Buffer20m_Id_1287.tif
# 🚚 Moved: Mask_Buffer20m_Id_1291.tif
# 🚚 Moved: Mask_Buffer20m_Id_1292.tif
# 🚚 Moved: Mask_Buffer20m_Id_1293.tif
# 🚚 Moved: Mask_Buffer20m_Id_1294.tif
# 🚚 Moved: Mask_Buffer20m_Id_1298.tif
# 🚚 Moved: Mask_Buffer20m_Id_1299.tif
# 🚚 Moved: Mask_Buffer20m_Id_1300.tif
# 🚚 Moved: Mask_Buffer20m_Id_1301.tif
# 🚚 Moved: Mask_Buffer20m_Id_1303.tif
# 🚚 Moved: Mask_Buffer20m_Id_1306.tif
# 🚚 Moved: Mask_Buffer20m_Id_1309.tif
# 🚚 Moved: Mask_Buffer20m_Id_1311.tif
# 🚚 Moved: Mask_Buffer20m_Id_1312.tif
# 🚚 Moved: Mask_Buffer20m_Id_1313.tif
# 🚚 Moved: Mask_Buffer20m_Id_1314.tif
# 🚚 Moved: Mask_Buffer20m_Id_1315.tif
# 🚚 Moved: Mask_Buffer20m_Id_1316.tif
# 🚚 Moved: Mask_Buffer20m_Id_1318.tif
# 🚚 Moved: Mask_Buffer20m_Id_1319.tif
# 🚚 Moved: Mask_Buffer20m_Id_1323.tif
# 🚚 Moved: Mask_Buffer20m_Id_1324.tif
# 🚚 Moved: Mask_Buffer20m_Id_1325.tif
# 🚚 Moved: Mask_Buffer20m_Id_1326.tif
# 🚚 Moved: Mask_Buffer20m_Id_1328.tif
# 🚚 Moved: Mask_Buffer20m_Id_1330.tif
# 🚚 Moved: Mask_Buffer20m_Id_1331.tif
# 🚚 Moved: Mask_Buffer20m_Id_1332.tif
# 🚚 Moved: Mask_Buffer20m_Id_1333.tif
# 🚚 Moved: Mask_Buffer20m_Id_1334.tif
# 🚚 Moved: Mask_Buffer20m_Id_1335.tif
# 🚚 Moved: Mask_Buffer20m_Id_1336.tif
# 🚚 Moved: Mask_Buffer20m_Id_1337.tif
# 🚚 Moved: Mask_Buffer20m_Id_1338.tif
# 🚚 Moved: Mask_Buffer20m_Id_1339.tif
# 🚚 Moved: Mask_Buffer20m_Id_1340.tif
# 🚚 Moved: Mask_Buffer20m_Id_1341.tif
# 🚚 Moved: Mask_Buffer20m_Id_1342.tif
# 🚚 Moved: Mask_Buffer20m_Id_1343.tif
# 🚚 Moved: Mask_Buffer20m_Id_1344.tif
# 🚚 Moved: Mask_Buffer20m_Id_1345.tif
# 🚚 Moved: Mask_Buffer20m_Id_1347.tif
# 🚚 Moved: Mask_Buffer20m_Id_1348.tif
# 🚚 Moved: Mask_Buffer20m_Id_1349.tif
# 🚚 Moved: Mask_Buffer20m_Id_1350.tif
# 🚚 Moved: Mask_Buffer20m_Id_1351.tif
# 🚚 Moved: Mask_Buffer20m_Id_1352.tif
# 🚚 Moved: Mask_Buffer20m_Id_1353.tif
# 🚚 Moved: Mask_Buffer20m_Id_1355.tif
# 🚚 Moved: Mask_Buffer20m_Id_1357.tif
# 🚚 Moved: Mask_Buffer20m_Id_1358.tif
# 🚚 Moved: Mask_Buffer20m_Id_1359.tif
# 🚚 Moved: Mask_Buffer20m_Id_1360.tif
# 🚚 Moved: Mask_Buffer20m_Id_1361.tif
# 🚚 Moved: Mask_Buffer20m_Id_1363.tif
# 🚚 Moved: Mask_Buffer20m_Id_1364.tif
# 🚚 Moved: Mask_Buffer20m_Id_1366.tif
# 🚚 Moved: Mask_Buffer20m_Id_1368.tif
# 🚚 Moved: Mask_Buffer20m_Id_1369.tif
# 🚚 Moved: Mask_Buffer20m_Id_1370.tif
# 🚚 Moved: Mask_Buffer20m_Id_1371.tif
# 🚚 Moved: Mask_Buffer20m_Id_1372.tif
# 🚚 Moved: Mask_Buffer20m_Id_1373.tif
# 🚚 Moved: Mask_Buffer20m_Id_1374.tif
# 🚚 Moved: Mask_Buffer20m_Id_1375.tif
# 🚚 Moved: Mask_Buffer20m_Id_1376.tif
# 🚚 Moved: Mask_Buffer20m_Id_1378.tif
# 🚚 Moved: Mask_Buffer20m_Id_1380.tif
# 🚚 Moved: Mask_Buffer20m_Id_1381.tif
# 🚚 Moved: Mask_Buffer20m_Id_1382.tif
# 🚚 Moved: Mask_Buffer20m_Id_1383.tif
# 🚚 Moved: Mask_Buffer20m_Id_1384.tif
# 🚚 Moved: Mask_Buffer20m_Id_1385.tif
# 🚚 Moved: Mask_Buffer20m_Id_1386.tif
# 🚚 Moved: Mask_Buffer20m_Id_1387.tif
# 🚚 Moved: Mask_Buffer20m_Id_1389.tif
# 🚚 Moved: Mask_Buffer20m_Id_1392.tif
# 🚚 Moved: Mask_Buffer20m_Id_1396.tif
# 🚚 Moved: Mask_Buffer20m_Id_1397.tif
# 🚚 Moved: Mask_Buffer20m_Id_1399.tif
# 🚚 Moved: Mask_Buffer20m_Id_1400.tif
# 🚚 Moved: Mask_Buffer20m_Id_1401.tif
# 🚚 Moved: Mask_Buffer20m_Id_1402.tif
# 🚚 Moved: Mask_Buffer20m_Id_1403.tif
# 🚚 Moved: Mask_Buffer20m_Id_1404.tif
# 🚚 Moved: Mask_Buffer20m_Id_1405.tif
# 🚚 Moved: Mask_Buffer20m_Id_1406.tif
# 🚚 Moved: Mask_Buffer20m_Id_1407.tif
# 🚚 Moved: Mask_Buffer20m_Id_1408.tif
# 🚚 Moved: Mask_Buffer20m_Id_1409.tif
# 🚚 Moved: Mask_Buffer20m_Id_1410.tif
# 🚚 Moved: Mask_Buffer20m_Id_1411.tif
# 🚚 Moved: Mask_Buffer20m_Id_1412.tif
# 🚚 Moved: Mask_Buffer20m_Id_1413.tif
# 🚚 Moved: Mask_Buffer20m_Id_1414.tif
# 🚚 Moved: Mask_Buffer20m_Id_1415.tif
# 🚚 Moved: Mask_Buffer20m_Id_1416.tif
# 🚚 Moved: Mask_Buffer20m_Id_1417.tif
# 🚚 Moved: Mask_Buffer20m_Id_1418.tif
# 🚚 Moved: Mask_Buffer20m_Id_1419.tif
# 🚚 Moved: Mask_Buffer20m_Id_1420.tif
# 🚚 Moved: Mask_Buffer20m_Id_1421.tif
# 🚚 Moved: Mask_Buffer20m_Id_1423.tif
# 🚚 Moved: Mask_Buffer20m_Id_1424.tif
# 🚚 Moved: Mask_Buffer20m_Id_1427.tif
# 🚚 Moved: Mask_Buffer20m_Id_1428.tif
# 🚚 Moved: Mask_Buffer20m_Id_1429.tif
# 🚚 Moved: Mask_Buffer20m_Id_1430.tif
# 🚚 Moved: Mask_Buffer20m_Id_1431.tif
# 🚚 Moved: Mask_Buffer20m_Id_1432.tif
# 🚚 Moved: Mask_Buffer20m_Id_1433.tif
# 🚚 Moved: Mask_Buffer20m_Id_1434.tif
# 🚚 Moved: Mask_Buffer20m_Id_1435.tif
# 🚚 Moved: Mask_Buffer20m_Id_1436.tif
# 🚚 Moved: Mask_Buffer20m_Id_1437.tif
# 🚚 Moved: Mask_Buffer20m_Id_1438.tif
# 🚚 Moved: Mask_Buffer20m_Id_1439.tif
# 🚚 Moved: Mask_Buffer20m_Id_1440.tif
# 🚚 Moved: Mask_Buffer20m_Id_1441.tif
# 🚚 Moved: Mask_Buffer20m_Id_1442.tif
# 🚚 Moved: Mask_Buffer20m_Id_1444.tif
# 🚚 Moved: Mask_Buffer20m_Id_1445.tif
# 🚚 Moved: Mask_Buffer20m_Id_1446.tif
# 🚚 Moved: Mask_Buffer20m_Id_1447.tif
# 🚚 Moved: Mask_Buffer20m_Id_1448.tif
# 🚚 Moved: Mask_Buffer20m_Id_1449.tif
# 🚚 Moved: Mask_Buffer20m_Id_1450.tif
# 🚚 Moved: Mask_Buffer20m_Id_1451.tif
# 🚚 Moved: Mask_Buffer20m_Id_1453.tif
# 🚚 Moved: Mask_Buffer20m_Id_1454.tif
# 🚚 Moved: Mask_Buffer20m_Id_1455.tif
# 🚚 Moved: Mask_Buffer20m_Id_1457.tif
# 🚚 Moved: Mask_Buffer20m_Id_1458.tif
# 🚚 Moved: Mask_Buffer20m_Id_1459.tif
# 🚚 Moved: Mask_Buffer20m_Id_1460.tif
# 🚚 Moved: Mask_Buffer20m_Id_1461.tif
# 🚚 Moved: Mask_Buffer20m_Id_1462.tif
# 🚚 Moved: Mask_Buffer20m_Id_1463.tif
# 🚚 Moved: Mask_Buffer20m_Id_1464.tif
# 🚚 Moved: Mask_Buffer20m_Id_1465.tif
# 🚚 Moved: Mask_Buffer20m_Id_1466.tif
# 🚚 Moved: Mask_Buffer20m_Id_1467.tif
# 🚚 Moved: Mask_Buffer20m_Id_1468.tif
# 🚚 Moved: Mask_Buffer20m_Id_1469.tif
# 🚚 Moved: Mask_Buffer20m_Id_1470.tif
# 🚚 Moved: Mask_Buffer20m_Id_1471.tif
# 🚚 Moved: Mask_Buffer20m_Id_1472.tif
# 🚚 Moved: Mask_Buffer20m_Id_1473.tif
# 🚚 Moved: Mask_Buffer20m_Id_1474.tif
# 🚚 Moved: Mask_Buffer20m_Id_1475.tif
# 🚚 Moved: Mask_Buffer20m_Id_1476.tif
# 🚚 Moved: Mask_Buffer20m_Id_1477.tif
# 🚚 Moved: Mask_Buffer20m_Id_1479.tif
# 🚚 Moved: Mask_Buffer20m_Id_1480.tif
# 🚚 Moved: Mask_Buffer20m_Id_1481.tif
# 🚚 Moved: Mask_Buffer20m_Id_1482.tif
# 🚚 Moved: Mask_Buffer20m_Id_1483.tif
# 🚚 Moved: Mask_Buffer20m_Id_1484.tif
# 🚚 Moved: Mask_Buffer20m_Id_1485.tif
# 🚚 Moved: Mask_Buffer20m_Id_1486.tif
# 🚚 Moved: Mask_Buffer20m_Id_1487.tif
# 🚚 Moved: Mask_Buffer20m_Id_1488.tif
# 🚚 Moved: Mask_Buffer20m_Id_1490.tif
# 🚚 Moved: Mask_Buffer20m_Id_1491.tif
# 🚚 Moved: Mask_Buffer20m_Id_1492.tif
# 🚚 Moved: Mask_Buffer20m_Id_1493.tif
# 🚚 Moved: Mask_Buffer20m_Id_1494.tif
# 🚚 Moved: Mask_Buffer20m_Id_1496.tif
# 🚚 Moved: Mask_Buffer20m_Id_1497.tif
# 🚚 Moved: Mask_Buffer20m_Id_1498.tif
# 🚚 Moved: Mask_Buffer20m_Id_1500.tif
# 🚚 Moved: Mask_Buffer20m_Id_1501.tif
# 🚚 Moved: Mask_Buffer20m_Id_1502.tif
# 🚚 Moved: Mask_Buffer20m_Id_1503.tif
# 🚚 Moved: Mask_Buffer20m_Id_1504.tif
# 🚚 Moved: Mask_Buffer20m_Id_1505.tif
# 🚚 Moved: Mask_Buffer20m_Id_1506.tif
# 🚚 Moved: Mask_Buffer20m_Id_1507.tif
# 🚚 Moved: Mask_Buffer20m_Id_1508.tif
# 🚚 Moved: Mask_Buffer20m_Id_1509.tif
# 🚚 Moved: Mask_Buffer20m_Id_1510.tif
# 🚚 Moved: Mask_Buffer20m_Id_1511.tif
# 🚚 Moved: Mask_Buffer20m_Id_1512.tif
# 🚚 Moved: Mask_Buffer20m_Id_1513.tif
# 🚚 Moved: Mask_Buffer20m_Id_1514.tif
# 🚚 Moved: Mask_Buffer20m_Id_1515.tif
# 🚚 Moved: Mask_Buffer20m_Id_1516.tif
# 🚚 Moved: Mask_Buffer20m_Id_1518.tif
# 🚚 Moved: Mask_Buffer20m_Id_1519.tif
# 🚚 Moved: Mask_Buffer20m_Id_1520.tif
# 🚚 Moved: Mask_Buffer20m_Id_1522.tif
# 🚚 Moved: Mask_Buffer20m_Id_1524.tif
# 🚚 Moved: Mask_Buffer20m_Id_1525.tif
# 🚚 Moved: Mask_Buffer20m_Id_1526.tif
# 🚚 Moved: Mask_Buffer20m_Id_1527.tif
# 🚚 Moved: Mask_Buffer20m_Id_1528.tif
# 🚚 Moved: Mask_Buffer20m_Id_1529.tif
# 🚚 Moved: Mask_Buffer20m_Id_1530.tif
# 🚚 Moved: Mask_Buffer20m_Id_1531.tif
# 🚚 Moved: Mask_Buffer20m_Id_1532.tif
# 🚚 Moved: Mask_Buffer20m_Id_1533.tif
# 🚚 Moved: Mask_Buffer20m_Id_1535.tif
# 🚚 Moved: Mask_Buffer20m_Id_1537.tif
# 🚚 Moved: Mask_Buffer20m_Id_1538.tif
# 🚚 Moved: Mask_Buffer20m_Id_1539.tif
# 🚚 Moved: Mask_Buffer20m_Id_1540.tif
# 🚚 Moved: Mask_Buffer20m_Id_1541.tif
# 🚚 Moved: Mask_Buffer20m_Id_1542.tif
# 🚚 Moved: Mask_Buffer20m_Id_1543.tif
# 🚚 Moved: Mask_Buffer20m_Id_1544.tif
# 🚚 Moved: Mask_Buffer20m_Id_1587.tif
# 🚚 Moved: Mask_Buffer20m_Id_1588.tif
# 🚚 Moved: Mask_Buffer20m_Id_1589.tif
# 🚚 Moved: Mask_Buffer20m_Id_1590.tif
# 🚚 Moved: Mask_Buffer20m_Id_1591.tif
# 🚚 Moved: Mask_Buffer20m_Id_1592.tif
# 🚚 Moved: Mask_Buffer20m_Id_1593.tif
# 🚚 Moved: Mask_Buffer20m_Id_1594.tif
# 🚚 Moved: Mask_Buffer20m_Id_1595.tif
# 🚚 Moved: Mask_Buffer20m_Id_1596.tif
# 🚚 Moved: Mask_Buffer20m_Id_1597.tif
# 🚚 Moved: Mask_Buffer20m_Id_1598.tif
# 🚚 Moved: Mask_Buffer20m_Id_1599.tif
# 🚚 Moved: Mask_Buffer20m_Id_1600.tif
# 🚚 Moved: Mask_Buffer20m_Id_1601.tif
# 🚚 Moved: Mask_Buffer20m_Id_1602.tif
# 🚚 Moved: Mask_Buffer20m_Id_1603.tif
# 🚚 Moved: Mask_Buffer20m_Id_1604.tif
# 🚚 Moved: Mask_Buffer20m_Id_1605.tif
# 🚚 Moved: Mask_Buffer20m_Id_1606.tif
# 🚚 Moved: Mask_Buffer20m_Id_1607.tif
# 🚚 Moved: Mask_Buffer20m_Id_1608.tif
# 🚚 Moved: Mask_Buffer20m_Id_1609.tif
# 🚚 Moved: Mask_Buffer20m_Id_1610.tif
# 🚚 Moved: Mask_Buffer20m_Id_1611.tif
# 🚚 Moved: Mask_Buffer20m_Id_1615.tif
# 🚚 Moved: Mask_Buffer20m_Id_1616.tif
# 🚚 Moved: Mask_Buffer20m_Id_1617.tif
# 🚚 Moved: Mask_Buffer20m_Id_1618.tif
# 🚚 Moved: Mask_Buffer20m_Id_1619.tif
# 🚚 Moved: Mask_Buffer20m_Id_1620.tif
# 🚚 Moved: Mask_Buffer20m_Id_1621.tif
# 🚚 Moved: Mask_Buffer20m_Id_1622.tif
# 🚚 Moved: Mask_Buffer20m_Id_1623.tif
# 🚚 Moved: Mask_Buffer20m_Id_1624.tif
# 🚚 Moved: Mask_Buffer20m_Id_1625.tif
# 🚚 Moved: Mask_Buffer20m_Id_1626.tif
# 🚚 Moved: Mask_Buffer20m_Id_1627.tif
# 🚚 Moved: Mask_Buffer20m_Id_1628.tif
# 🚚 Moved: Mask_Buffer20m_Id_1629.tif
# 🚚 Moved: Mask_Buffer20m_Id_1630.tif
# 🚚 Moved: Mask_Buffer20m_Id_1631.tif
# 🚚 Moved: Mask_Buffer20m_Id_1634.tif
# 🚚 Moved: Mask_Buffer20m_Id_1635.tif
# 🚚 Moved: Mask_Buffer20m_Id_1636.tif
# 🚚 Moved: Mask_Buffer20m_Id_1637.tif
# 🚚 Moved: Mask_Buffer20m_Id_1638.tif
# 🚚 Moved: Mask_Buffer20m_Id_1639.tif
# 🚚 Moved: Mask_Buffer20m_Id_1640.tif
# 🚚 Moved: Mask_Buffer20m_Id_1641.tif
# 🚚 Moved: Mask_Buffer20m_Id_1642.tif
# 🚚 Moved: Mask_Buffer20m_Id_1643.tif
# 🚚 Moved: Mask_Buffer20m_Id_1644.tif
# 🚚 Moved: Mask_Buffer20m_Id_1645.tif
# 🚚 Moved: Mask_Buffer20m_Id_1646.tif
# 🚚 Moved: Mask_Buffer20m_Id_1647.tif
# 🚚 Moved: Mask_Buffer20m_Id_1649.tif
# 🚚 Moved: Mask_Buffer20m_Id_1650.tif
# 🚚 Moved: Mask_Buffer20m_Id_1000.tif
# 🚚 Moved: Mask_Buffer20m_Id_1001.tif
# 🚚 Moved: Mask_Buffer20m_Id_1002.tif
# 🚚 Moved: Mask_Buffer20m_Id_1003.tif
# 🚚 Moved: Mask_Buffer20m_Id_1005.tif
# 🚚 Moved: Mask_Buffer20m_Id_1006.tif
# 🚚 Moved: Mask_Buffer20m_Id_1008.tif
# 🚚 Moved: Mask_Buffer20m_Id_1009.tif
# 🚚 Moved: Mask_Buffer20m_Id_1011.tif
# 🚚 Moved: Mask_Buffer20m_Id_1012.tif
# 🚚 Moved: Mask_Buffer20m_Id_1013.tif
# 🚚 Moved: Mask_Buffer20m_Id_1014.tif
# 🚚 Moved: Mask_Buffer20m_Id_1017.tif
# 🚚 Moved: Mask_Buffer20m_Id_1018.tif
# 🚚 Moved: Mask_Buffer20m_Id_1020.tif
# 🚚 Moved: Mask_Buffer20m_Id_1022.tif
# 🚚 Moved: Mask_Buffer20m_Id_1023.tif
# 🚚 Moved: Mask_Buffer20m_Id_1024.tif
# 🚚 Moved: Mask_Buffer20m_Id_1025.tif
# 🚚 Moved: Mask_Buffer20m_Id_1028.tif
# 🚚 Moved: Mask_Buffer20m_Id_1029.tif
# 🚚 Moved: Mask_Buffer20m_Id_1030.tif
# 🚚 Moved: Mask_Buffer20m_Id_1031.tif
# 🚚 Moved: Mask_Buffer20m_Id_1032.tif
# 🚚 Moved: Mask_Buffer20m_Id_1033.tif
# 🚚 Moved: Mask_Buffer20m_Id_1034.tif
# 🚚 Moved: Mask_Buffer20m_Id_1035.tif
# 🚚 Moved: Mask_Buffer20m_Id_1036.tif
# 🚚 Moved: Mask_Buffer20m_Id_1037.tif
# 🚚 Moved: Mask_Buffer20m_Id_1039.tif
# 🚚 Moved: Mask_Buffer20m_Id_1040.tif
# 🚚 Moved: Mask_Buffer20m_Id_1042.tif
# 🚚 Moved: Mask_Buffer20m_Id_1046.tif
# 🚚 Moved: Mask_Buffer20m_Id_1047.tif
# 🚚 Moved: Mask_Buffer20m_Id_1049.tif
# 🚚 Moved: Mask_Buffer20m_Id_1050.tif
# 🚚 Moved: Mask_Buffer20m_Id_1051.tif
# 🚚 Moved: Mask_Buffer20m_Id_1052.tif
# 🚚 Moved: Mask_Buffer20m_Id_1053.tif
# 🚚 Moved: Mask_Buffer20m_Id_1054.tif
# 🚚 Moved: Mask_Buffer20m_Id_1056.tif
# 🚚 Moved: Mask_Buffer20m_Id_1057.tif
# 🚚 Moved: Mask_Buffer20m_Id_1058.tif
# 🚚 Moved: Mask_Buffer20m_Id_1059.tif
# 🚚 Moved: Mask_Buffer20m_Id_1060.tif
# 🚚 Moved: Mask_Buffer20m_Id_1061.tif
# 🚚 Moved: Mask_Buffer20m_Id_1062.tif
# 🚚 Moved: Mask_Buffer20m_Id_1063.tif
# 🚚 Moved: Mask_Buffer20m_Id_1064.tif
# 🚚 Moved: Mask_Buffer20m_Id_1065.tif
# 🚚 Moved: Mask_Buffer20m_Id_1066.tif
# 🚚 Moved: Mask_Buffer20m_Id_1067.tif
# 🚚 Moved: Mask_Buffer20m_Id_1070.tif
# 🚚 Moved: Mask_Buffer20m_Id_1072.tif
# 🚚 Moved: Mask_Buffer20m_Id_1073.tif
# 🚚 Moved: Mask_Buffer20m_Id_1074.tif
# 🚚 Moved: Mask_Buffer20m_Id_1075.tif
# 🚚 Moved: Mask_Buffer20m_Id_1076.tif
# 🚚 Moved: Mask_Buffer20m_Id_1077.tif
# 🚚 Moved: Mask_Buffer20m_Id_1078.tif
# 🚚 Moved: Mask_Buffer20m_Id_1079.tif
# 🚚 Moved: Mask_Buffer20m_Id_1080.tif
# 🚚 Moved: Mask_Buffer20m_Id_1081.tif
# 🚚 Moved: Mask_Buffer20m_Id_1082.tif
# 🚚 Moved: Mask_Buffer20m_Id_1084.tif
# 🚚 Moved: Mask_Buffer20m_Id_1085.tif
# 🚚 Moved: Mask_Buffer20m_Id_1086.tif
# 🚚 Moved: Mask_Buffer20m_Id_1087.tif
# 🚚 Moved: Mask_Buffer20m_Id_1088.tif
# 🚚 Moved: Mask_Buffer20m_Id_1089.tif
# 🚚 Moved: Mask_Buffer20m_Id_1090.tif
# 🚚 Moved: Mask_Buffer20m_Id_1091.tif
# 🚚 Moved: Mask_Buffer20m_Id_1092.tif
# 🚚 Moved: Mask_Buffer20m_Id_1093.tif
# 🚚 Moved: Mask_Buffer20m_Id_1094.tif
# 🚚 Moved: Mask_Buffer20m_Id_1095.tif
# 🚚 Moved: Mask_Buffer20m_Id_1096.tif
# 🚚 Moved: Mask_Buffer20m_Id_1097.tif
# 🚚 Moved: Mask_Buffer20m_Id_1098.tif
# 🚚 Moved: Mask_Buffer20m_Id_1099.tif
# 🚚 Moved: Mask_Buffer20m_Id_1100.tif
# 🚚 Moved: Mask_Buffer20m_Id_1101.tif
# 🚚 Moved: Mask_Buffer20m_Id_1103.tif
# 🚚 Moved: Mask_Buffer20m_Id_1104.tif
# 🚚 Moved: Mask_Buffer20m_Id_1105.tif
# 🚚 Moved: Mask_Buffer20m_Id_1106.tif
# 🚚 Moved: Mask_Buffer20m_Id_1107.tif
# 🚚 Moved: Mask_Buffer20m_Id_1108.tif
# 🚚 Moved: Mask_Buffer20m_Id_1109.tif
# 🚚 Moved: Mask_Buffer20m_Id_1111.tif
# 🚚 Moved: Mask_Buffer20m_Id_1112.tif
# 🚚 Moved: Mask_Buffer20m_Id_1113.tif
# 🚚 Moved: Mask_Buffer20m_Id_1114.tif
# 🚚 Moved: Mask_Buffer20m_Id_1115.tif
# 🚚 Moved: Mask_Buffer20m_Id_1116.tif
# 🚚 Moved: Mask_Buffer20m_Id_1117.tif
# 🚚 Moved: Mask_Buffer20m_Id_1118.tif
# 🚚 Moved: Mask_Buffer20m_Id_1119.tif
# 🚚 Moved: Mask_Buffer20m_Id_1120.tif
# 🚚 Moved: Mask_Buffer20m_Id_1122.tif
# 🚚 Moved: Mask_Buffer20m_Id_1123.tif
# 🚚 Moved: Mask_Buffer20m_Id_1124.tif
# 🚚 Moved: Mask_Buffer20m_Id_1126.tif
# 🚚 Moved: Mask_Buffer20m_Id_1127.tif
# 🚚 Moved: Mask_Buffer20m_Id_1128.tif
# 🚚 Moved: Mask_Buffer20m_Id_1130.tif
# 🚚 Moved: Mask_Buffer20m_Id_1133.tif
# 🚚 Moved: Mask_Buffer20m_Id_1135.tif
# 🚚 Moved: Mask_Buffer20m_Id_1138.tif
# 🚚 Moved: Mask_Buffer20m_Id_1140.tif
# 🚚 Moved: Mask_Buffer20m_Id_1141.tif
# 🚚 Moved: Mask_Buffer20m_Id_1142.tif
# 🚚 Moved: Mask_Buffer20m_Id_1143.tif
# 🚚 Moved: Mask_Buffer20m_Id_1144.tif
# 🚚 Moved: Mask_Buffer20m_Id_1145.tif
# 🚚 Moved: Mask_Buffer20m_Id_1146.tif
# 🚚 Moved: Mask_Buffer20m_Id_1147.tif
# 🚚 Moved: Mask_Buffer20m_Id_1148.tif
# 🚚 Moved: Mask_Buffer20m_Id_1149.tif
# 🚚 Moved: Mask_Buffer20m_Id_1150.tif
# 🚚 Moved: Mask_Buffer20m_Id_1151.tif
# 🚚 Moved: Mask_Buffer20m_Id_1152.tif
# 🚚 Moved: Mask_Buffer20m_Id_1154.tif
# 🚚 Moved: Mask_Buffer20m_Id_1155.tif
# 🚚 Moved: Mask_Buffer20m_Id_1157.tif
# 🚚 Moved: Mask_Buffer20m_Id_1158.tif
# 🚚 Moved: Mask_Buffer20m_Id_1159.tif
# 🚚 Moved: Mask_Buffer20m_Id_1160.tif
# 🚚 Moved: Mask_Buffer20m_Id_1161.tif
# 🚚 Moved: Mask_Buffer20m_Id_1162.tif
# 🚚 Moved: Mask_Buffer20m_Id_1163.tif
# 🚚 Moved: Mask_Buffer20m_Id_1164.tif
# 🚚 Moved: Mask_Buffer20m_Id_1165.tif
# 🚚 Moved: Mask_Buffer20m_Id_1166.tif
# 🚚 Moved: Mask_Buffer20m_Id_1167.tif
# 🚚 Moved: Mask_Buffer20m_Id_1168.tif
# 🚚 Moved: Mask_Buffer20m_Id_1169.tif
# 🚚 Moved: Mask_Buffer20m_Id_1170.tif
# 🚚 Moved: Mask_Buffer20m_Id_1171.tif
# 🚚 Moved: Mask_Buffer20m_Id_1172.tif
# 🚚 Moved: Mask_Buffer20m_Id_1173.tif
# 🚚 Moved: Mask_Buffer20m_Id_1174.tif
# 🚚 Moved: Mask_Buffer20m_Id_1176.tif
# 🚚 Moved: Mask_Buffer20m_Id_1177.tif
# 🚚 Moved: Mask_Buffer20m_Id_1178.tif
# 🚚 Moved: Mask_Buffer20m_Id_1179.tif
# 🚚 Moved: Mask_Buffer20m_Id_1180.tif
# 🚚 Moved: Mask_Buffer20m_Id_1181.tif
# 🚚 Moved: Mask_Buffer20m_Id_1182.tif
# 🚚 Moved: Mask_Buffer20m_Id_1183.tif
# 🚚 Moved: Mask_Buffer20m_Id_1185.tif
# 🚚 Moved: Mask_Buffer20m_Id_1187.tif
# 🚚 Moved: Mask_Buffer20m_Id_1188.tif
# 🚚 Moved: Mask_Buffer20m_Id_1191.tif
# 🚚 Moved: Mask_Buffer20m_Id_1192.tif
# 🚚 Moved: Mask_Buffer20m_Id_1193.tif
# 🚚 Moved: Mask_Buffer20m_Id_1194.tif
# 🚚 Moved: Mask_Buffer20m_Id_1196.tif
# 🚚 Moved: Mask_Buffer20m_Id_1197.tif
# 🚚 Moved: Mask_Buffer20m_Id_1198.tif
# 🚚 Moved: Mask_Buffer20m_Id_1200.tif
# 🚚 Moved: Mask_Buffer20m_Id_1201.tif
# 🚚 Moved: Mask_Buffer20m_Id_1202.tif
# 🚚 Moved: Mask_Buffer20m_Id_1203.tif
# 🚚 Moved: Mask_Buffer20m_Id_1204.tif
# 🚚 Moved: Mask_Buffer20m_Id_1205.tif
# 🚚 Moved: Mask_Buffer20m_Id_1206.tif
# 🚚 Moved: Mask_Buffer20m_Id_1207.tif
# 🚚 Moved: Mask_Buffer20m_Id_1208.tif
# 🚚 Moved: Mask_Buffer20m_Id_1209.tif
# 🚚 Moved: Mask_Buffer20m_Id_800.tif
# 🚚 Moved: Mask_Buffer20m_Id_801.tif
# 🚚 Moved: Mask_Buffer20m_Id_802.tif
# 🚚 Moved: Mask_Buffer20m_Id_803.tif
# 🚚 Moved: Mask_Buffer20m_Id_804.tif
# 🚚 Moved: Mask_Buffer20m_Id_806.tif
# 🚚 Moved: Mask_Buffer20m_Id_807.tif
# 🚚 Moved: Mask_Buffer20m_Id_808.tif
# 🚚 Moved: Mask_Buffer20m_Id_809.tif
# 🚚 Moved: Mask_Buffer20m_Id_810.tif
# 🚚 Moved: Mask_Buffer20m_Id_811.tif
# 🚚 Moved: Mask_Buffer20m_Id_812.tif
# 🚚 Moved: Mask_Buffer20m_Id_813.tif
# 🚚 Moved: Mask_Buffer20m_Id_814.tif
# 🚚 Moved: Mask_Buffer20m_Id_815.tif
# 🚚 Moved: Mask_Buffer20m_Id_816.tif
# 🚚 Moved: Mask_Buffer20m_Id_818.tif
# 🚚 Moved: Mask_Buffer20m_Id_820.tif
# 🚚 Moved: Mask_Buffer20m_Id_821.tif
# 🚚 Moved: Mask_Buffer20m_Id_822.tif
# 🚚 Moved: Mask_Buffer20m_Id_823.tif
# 🚚 Moved: Mask_Buffer20m_Id_824.tif
# 🚚 Moved: Mask_Buffer20m_Id_825.tif
# 🚚 Moved: Mask_Buffer20m_Id_826.tif
# 🚚 Moved: Mask_Buffer20m_Id_827.tif
# 🚚 Moved: Mask_Buffer20m_Id_828.tif
# 🚚 Moved: Mask_Buffer20m_Id_829.tif
# 🚚 Moved: Mask_Buffer20m_Id_830.tif
# 🚚 Moved: Mask_Buffer20m_Id_831.tif
# 🚚 Moved: Mask_Buffer20m_Id_832.tif
# 🚚 Moved: Mask_Buffer20m_Id_833.tif
# 🚚 Moved: Mask_Buffer20m_Id_834.tif
# 🚚 Moved: Mask_Buffer20m_Id_835.tif
# 🚚 Moved: Mask_Buffer20m_Id_836.tif
# 🚚 Moved: Mask_Buffer20m_Id_837.tif
# 🚚 Moved: Mask_Buffer20m_Id_838.tif
# 🚚 Moved: Mask_Buffer20m_Id_839.tif
# 🚚 Moved: Mask_Buffer20m_Id_840.tif
# 🚚 Moved: Mask_Buffer20m_Id_842.tif
# 🚚 Moved: Mask_Buffer20m_Id_843.tif
# 🚚 Moved: Mask_Buffer20m_Id_844.tif
# 🚚 Moved: Mask_Buffer20m_Id_845.tif
# 🚚 Moved: Mask_Buffer20m_Id_846.tif
# 🚚 Moved: Mask_Buffer20m_Id_847.tif
# 🚚 Moved: Mask_Buffer20m_Id_848.tif
# 🚚 Moved: Mask_Buffer20m_Id_849.tif
# 🚚 Moved: Mask_Buffer20m_Id_850.tif
# 🚚 Moved: Mask_Buffer20m_Id_851.tif
# 🚚 Moved: Mask_Buffer20m_Id_852.tif
# 🚚 Moved: Mask_Buffer20m_Id_853.tif
# 🚚 Moved: Mask_Buffer20m_Id_854.tif
# 🚚 Moved: Mask_Buffer20m_Id_855.tif
# 🚚 Moved: Mask_Buffer20m_Id_856.tif
# 🚚 Moved: Mask_Buffer20m_Id_857.tif
# 🚚 Moved: Mask_Buffer20m_Id_858.tif
# 🚚 Moved: Mask_Buffer20m_Id_859.tif
# 🚚 Moved: Mask_Buffer20m_Id_860.tif
# 🚚 Moved: Mask_Buffer20m_Id_862.tif
# 🚚 Moved: Mask_Buffer20m_Id_863.tif
# 🚚 Moved: Mask_Buffer20m_Id_864.tif
# 🚚 Moved: Mask_Buffer20m_Id_869.tif
# 🚚 Moved: Mask_Buffer20m_Id_871.tif
# 🚚 Moved: Mask_Buffer20m_Id_872.tif
# 🚚 Moved: Mask_Buffer20m_Id_873.tif
# 🚚 Moved: Mask_Buffer20m_Id_874.tif
# 🚚 Moved: Mask_Buffer20m_Id_875.tif
# 🚚 Moved: Mask_Buffer20m_Id_876.tif
# 🚚 Moved: Mask_Buffer20m_Id_877.tif
# 🚚 Moved: Mask_Buffer20m_Id_878.tif
# 🚚 Moved: Mask_Buffer20m_Id_879.tif
# 🚚 Moved: Mask_Buffer20m_Id_882.tif
# 🚚 Moved: Mask_Buffer20m_Id_883.tif
# 🚚 Moved: Mask_Buffer20m_Id_884.tif
# 🚚 Moved: Mask_Buffer20m_Id_885.tif
# 🚚 Moved: Mask_Buffer20m_Id_886.tif
# 🚚 Moved: Mask_Buffer20m_Id_887.tif
# 🚚 Moved: Mask_Buffer20m_Id_888.tif
# 🚚 Moved: Mask_Buffer20m_Id_889.tif
# 🚚 Moved: Mask_Buffer20m_Id_890.tif
# 🚚 Moved: Mask_Buffer20m_Id_891.tif
# 🚚 Moved: Mask_Buffer20m_Id_892.tif
# 🚚 Moved: Mask_Buffer20m_Id_894.tif
# 🚚 Moved: Mask_Buffer20m_Id_895.tif
# 🚚 Moved: Mask_Buffer20m_Id_898.tif
# 🚚 Moved: Mask_Buffer20m_Id_899.tif
# 🚚 Moved: Mask_Buffer20m_Id_900.tif
# 🚚 Moved: Mask_Buffer20m_Id_901.tif
# 🚚 Moved: Mask_Buffer20m_Id_902.tif
# 🚚 Moved: Mask_Buffer20m_Id_904.tif
# 🚚 Moved: Mask_Buffer20m_Id_907.tif
# 🚚 Moved: Mask_Buffer20m_Id_910.tif
# 🚚 Moved: Mask_Buffer20m_Id_911.tif
# 🚚 Moved: Mask_Buffer20m_Id_912.tif
# 🚚 Moved: Mask_Buffer20m_Id_913.tif
# 🚚 Moved: Mask_Buffer20m_Id_915.tif
# 🚚 Moved: Mask_Buffer20m_Id_916.tif
# 🚚 Moved: Mask_Buffer20m_Id_917.tif
# 🚚 Moved: Mask_Buffer20m_Id_919.tif
# 🚚 Moved: Mask_Buffer20m_Id_920.tif
# 🚚 Moved: Mask_Buffer20m_Id_921.tif
# 🚚 Moved: Mask_Buffer20m_Id_922.tif
# 🚚 Moved: Mask_Buffer20m_Id_923.tif
# 🚚 Moved: Mask_Buffer20m_Id_924.tif
# 🚚 Moved: Mask_Buffer20m_Id_926.tif
# 🚚 Moved: Mask_Buffer20m_Id_927.tif
# 🚚 Moved: Mask_Buffer20m_Id_929.tif
# 🚚 Moved: Mask_Buffer20m_Id_930.tif
# 🚚 Moved: Mask_Buffer20m_Id_931.tif
# 🚚 Moved: Mask_Buffer20m_Id_932.tif
# 🚚 Moved: Mask_Buffer20m_Id_933.tif
# 🚚 Moved: Mask_Buffer20m_Id_934.tif
# 🚚 Moved: Mask_Buffer20m_Id_935.tif
# 🚚 Moved: Mask_Buffer20m_Id_936.tif
# 🚚 Moved: Mask_Buffer20m_Id_937.tif
# 🚚 Moved: Mask_Buffer20m_Id_938.tif
# 🚚 Moved: Mask_Buffer20m_Id_939.tif
# 🚚 Moved: Mask_Buffer20m_Id_940.tif
# 🚚 Moved: Mask_Buffer20m_Id_941.tif
# 🚚 Moved: Mask_Buffer20m_Id_942.tif
# 🚚 Moved: Mask_Buffer20m_Id_943.tif
# 🚚 Moved: Mask_Buffer20m_Id_944.tif
# 🚚 Moved: Mask_Buffer20m_Id_945.tif
# 🚚 Moved: Mask_Buffer20m_Id_946.tif
# 🚚 Moved: Mask_Buffer20m_Id_947.tif
# 🚚 Moved: Mask_Buffer20m_Id_948.tif
# 🚚 Moved: Mask_Buffer20m_Id_949.tif
# 🚚 Moved: Mask_Buffer20m_Id_950.tif
# 🚚 Moved: Mask_Buffer20m_Id_955.tif
# 🚚 Moved: Mask_Buffer20m_Id_956.tif
# 🚚 Moved: Mask_Buffer20m_Id_959.tif
# 🚚 Moved: Mask_Buffer20m_Id_960.tif
# 🚚 Moved: Mask_Buffer20m_Id_961.tif
# 🚚 Moved: Mask_Buffer20m_Id_962.tif
# 🚚 Moved: Mask_Buffer20m_Id_964.tif
# 🚚 Moved: Mask_Buffer20m_Id_965.tif
# 🚚 Moved: Mask_Buffer20m_Id_966.tif
# 🚚 Moved: Mask_Buffer20m_Id_967.tif
# 🚚 Moved: Mask_Buffer20m_Id_968.tif
# 🚚 Moved: Mask_Buffer20m_Id_969.tif
# 🚚 Moved: Mask_Buffer20m_Id_971.tif
# 🚚 Moved: Mask_Buffer20m_Id_972.tif
# 🚚 Moved: Mask_Buffer20m_Id_973.tif
# 🚚 Moved: Mask_Buffer20m_Id_976.tif
# 🚚 Moved: Mask_Buffer20m_Id_978.tif
# 🚚 Moved: Mask_Buffer20m_Id_979.tif
# 🚚 Moved: Mask_Buffer20m_Id_981.tif
# 🚚 Moved: Mask_Buffer20m_Id_983.tif
# 🚚 Moved: Mask_Buffer20m_Id_984.tif
# 🚚 Moved: Mask_Buffer20m_Id_985.tif
# 🚚 Moved: Mask_Buffer20m_Id_987.tif
# 🚚 Moved: Mask_Buffer20m_Id_988.tif
# 🚚 Moved: Mask_Buffer20m_Id_989.tif
# 🚚 Moved: Mask_Buffer20m_Id_990.tif
# 🚚 Moved: Mask_Buffer20m_Id_991.tif
# 🚚 Moved: Mask_Buffer20m_Id_992.tif
# 🚚 Moved: Mask_Buffer20m_Id_993.tif
# 🚚 Moved: Mask_Buffer20m_Id_994.tif
# 🚚 Moved: Mask_Buffer20m_Id_995.tif
# 🚚 Moved: Mask_Buffer20m_Id_996.tif
# 🚚 Moved: Mask_Buffer20m_Id_998.tif
# 🚚 Moved: Mask_Buffer20m_Id_999.tif
# 🚚 Moved: Mask_Buffer20m_Id_1210.tif
# ✅ All .tif files moved and deleted from source.

# %% [markdown]
# Check for any missing images to the corresponding new masks and add them.

# %%
# 📁 Define paths
mask_folder = "/content/drive/MyDrive/training_masks"                   # Folder with mask files
primary_image_folder = "/content/drive/MyDrive/Sentinel_training" # Destination folder for images
third_image_folder = "/content/drive/MyDrive/P2 - Amazon ITU - PESU/GEE_Exports_all"     # Source folder with 'id_800.tif'

# 🧠 Regex to extract ID from mask filenames like Mask_Buffer20m_Id_800.tif
pattern = re.compile(r"Mask_Buffer20m_Id_(\d+)\.tif")

# 🔁 Process each mask
for mask_file in os.listdir(mask_folder):
    if not mask_file.lower().endswith(".tif"):
        continue

    match = pattern.match(mask_file)
    if not match:
        continue

    id_number = match.group(1)
    target_filename = f"Sentinel_AllBands_Training_Id_{id_number}.tif"
    target_path = os.path.join(primary_image_folder, target_filename)

    # Check if file already exists in primary image folder
    if os.path.exists(target_path):
        print(f"✔️ Image already exists: {target_filename}")
        continue

    # Check if corresponding image exists in the third folder
    source_filename = f"id_{id_number}.tif"
    source_path = os.path.join(third_image_folder, source_filename)

    if os.path.exists(source_path):
        shutil.copyfile(source_path, target_path)
        print(f"✅ Copied and renamed: {source_filename} → {target_filename}")
    else:
        print(f"⚠️ Not found in backup: {source_filename}")

print("🎉 Done copying missing images.")
# Out:
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_1.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_2.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_9.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_10.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_11.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_17.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_18.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_19.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_20.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_21.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_22.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_23.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_28.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_30.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_31.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_32.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_33.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_36.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_37.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_38.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_39.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_40.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_41.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_42.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_44.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_45.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_46.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_55.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_56.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_57.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_58.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_59.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_60.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_61.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_62.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_63.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_64.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_65.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_66.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_67.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_68.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_69.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_71.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_73.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_74.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_75.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_76.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_77.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_78.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_79.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_85.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_88.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_89.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_98.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_99.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_100.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_101.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_102.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_103.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_105.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_106.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_107.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_108.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_110.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_111.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_114.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_115.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_118.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_120.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_121.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_123.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_124.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_125.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_126.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_130.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_131.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_132.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_135.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_136.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_137.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_138.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_139.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_141.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_143.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_144.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_145.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_146.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_147.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_148.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_149.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_150.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_151.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_152.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_154.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_155.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_156.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_157.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_160.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_161.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_162.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_163.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_165.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_169.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_172.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_175.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_176.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_179.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_182.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_183.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_184.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_185.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_186.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_187.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_188.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_189.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_190.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_192.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_194.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_196.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_197.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_198.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_199.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_200.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_201.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_202.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_203.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_204.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_205.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_206.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_207.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_208.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_209.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_210.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_211.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_213.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_214.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_215.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_216.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_217.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_218.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_219.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_220.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_221.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_222.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_223.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_224.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_225.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_227.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_228.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_229.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_212.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_195.tif
# ✔️ Image already exists: Sentinel_AllBands_Training_Id_226.tif
# ✅ Copied and renamed: id_1211.tif → Sentinel_AllBands_Training_Id_1211.tif
# ✅ Copied and renamed: id_1216.tif → Sentinel_AllBands_Training_Id_1216.tif
# ✅ Copied and renamed: id_1217.tif → Sentinel_AllBands_Training_Id_1217.tif
# ✅ Copied and renamed: id_1219.tif → Sentinel_AllBands_Training_Id_1219.tif
# ✅ Copied and renamed: id_1222.tif → Sentinel_AllBands_Training_Id_1222.tif
# ✅ Copied and renamed: id_1224.tif → Sentinel_AllBands_Training_Id_1224.tif
# ✅ Copied and renamed: id_1226.tif → Sentinel_AllBands_Training_Id_1226.tif
# ✅ Copied and renamed: id_1227.tif → Sentinel_AllBands_Training_Id_1227.tif
# ✅ Copied and renamed: id_1228.tif → Sentinel_AllBands_Training_Id_1228.tif
# ✅ Copied and renamed: id_1229.tif → Sentinel_AllBands_Training_Id_1229.tif
# ✅ Copied and renamed: id_1231.tif → Sentinel_AllBands_Training_Id_1231.tif
# ✅ Copied and renamed: id_1232.tif → Sentinel_AllBands_Training_Id_1232.tif
# ✅ Copied and renamed: id_1233.tif → Sentinel_AllBands_Training_Id_1233.tif
# ✅ Copied and renamed: id_1234.tif → Sentinel_AllBands_Training_Id_1234.tif
# ✅ Copied and renamed: id_1236.tif → Sentinel_AllBands_Training_Id_1236.tif
# ✅ Copied and renamed: id_1237.tif → Sentinel_AllBands_Training_Id_1237.tif
# ✅ Copied and renamed: id_1239.tif → Sentinel_AllBands_Training_Id_1239.tif
# ✅ Copied and renamed: id_1240.tif → Sentinel_AllBands_Training_Id_1240.tif
# ✅ Copied and renamed: id_1241.tif → Sentinel_AllBands_Training_Id_1241.tif
# ✅ Copied and renamed: id_1242.tif → Sentinel_AllBands_Training_Id_1242.tif
# ✅ Copied and renamed: id_1244.tif → Sentinel_AllBands_Training_Id_1244.tif
# ✅ Copied and renamed: id_1245.tif → Sentinel_AllBands_Training_Id_1245.tif
# ✅ Copied and renamed: id_1248.tif → Sentinel_AllBands_Training_Id_1248.tif
# ✅ Copied and renamed: id_1252.tif → Sentinel_AllBands_Training_Id_1252.tif
# ✅ Copied and renamed: id_1254.tif → Sentinel_AllBands_Training_Id_1254.tif
# ✅ Copied and renamed: id_1255.tif → Sentinel_AllBands_Training_Id_1255.tif
# ✅ Copied and renamed: id_1256.tif → Sentinel_AllBands_Training_Id_1256.tif
# ✅ Copied and renamed: id_1258.tif → Sentinel_AllBands_Training_Id_1258.tif
# ✅ Copied and renamed: id_1260.tif → Sentinel_AllBands_Training_Id_1260.tif
# ✅ Copied and renamed: id_1261.tif → Sentinel_AllBands_Training_Id_1261.tif
# ✅ Copied and renamed: id_1262.tif → Sentinel_AllBands_Training_Id_1262.tif
# ✅ Copied and renamed: id_1263.tif → Sentinel_AllBands_Training_Id_1263.tif
# ✅ Copied and renamed: id_1265.tif → Sentinel_AllBands_Training_Id_1265.tif
# ✅ Copied and renamed: id_1266.tif → Sentinel_AllBands_Training_Id_1266.tif
# ✅ Copied and renamed: id_1267.tif → Sentinel_AllBands_Training_Id_1267.tif
# ✅ Copied and renamed: id_1268.tif → Sentinel_AllBands_Training_Id_1268.tif
# ✅ Copied and renamed: id_1270.tif → Sentinel_AllBands_Training_Id_1270.tif
# ✅ Copied and renamed: id_1271.tif → Sentinel_AllBands_Training_Id_1271.tif
# ✅ Copied and renamed: id_1272.tif → Sentinel_AllBands_Training_Id_1272.tif
# ✅ Copied and renamed: id_1273.tif → Sentinel_AllBands_Training_Id_1273.tif
# ✅ Copied and renamed: id_1275.tif → Sentinel_AllBands_Training_Id_1275.tif
# ✅ Copied and renamed: id_1277.tif → Sentinel_AllBands_Training_Id_1277.tif
# ✅ Copied and renamed: id_1278.tif → Sentinel_AllBands_Training_Id_1278.tif
# ✅ Copied and renamed: id_1279.tif → Sentinel_AllBands_Training_Id_1279.tif
# ✅ Copied and renamed: id_1281.tif → Sentinel_AllBands_Training_Id_1281.tif
# ✅ Copied and renamed: id_1282.tif → Sentinel_AllBands_Training_Id_1282.tif
# ✅ Copied and renamed: id_1283.tif → Sentinel_AllBands_Training_Id_1283.tif
# ✅ Copied and renamed: id_1284.tif → Sentinel_AllBands_Training_Id_1284.tif
# ✅ Copied and renamed: id_1286.tif → Sentinel_AllBands_Training_Id_1286.tif
# ✅ Copied and renamed: id_1287.tif → Sentinel_AllBands_Training_Id_1287.tif
# ✅ Copied and renamed: id_1291.tif → Sentinel_AllBands_Training_Id_1291.tif
# ✅ Copied and renamed: id_1292.tif → Sentinel_AllBands_Training_Id_1292.tif
# ✅ Copied and renamed: id_1293.tif → Sentinel_AllBands_Training_Id_1293.tif
# ✅ Copied and renamed: id_1294.tif → Sentinel_AllBands_Training_Id_1294.tif
# ✅ Copied and renamed: id_1298.tif → Sentinel_AllBands_Training_Id_1298.tif
# ✅ Copied and renamed: id_1299.tif → Sentinel_AllBands_Training_Id_1299.tif
# ✅ Copied and renamed: id_1300.tif → Sentinel_AllBands_Training_Id_1300.tif
# ✅ Copied and renamed: id_1301.tif → Sentinel_AllBands_Training_Id_1301.tif
# ✅ Copied and renamed: id_1303.tif → Sentinel_AllBands_Training_Id_1303.tif
# ✅ Copied and renamed: id_1306.tif → Sentinel_AllBands_Training_Id_1306.tif
# ✅ Copied and renamed: id_1309.tif → Sentinel_AllBands_Training_Id_1309.tif
# ✅ Copied and renamed: id_1311.tif → Sentinel_AllBands_Training_Id_1311.tif
# ✅ Copied and renamed: id_1312.tif → Sentinel_AllBands_Training_Id_1312.tif
# ✅ Copied and renamed: id_1313.tif → Sentinel_AllBands_Training_Id_1313.tif
# ✅ Copied and renamed: id_1314.tif → Sentinel_AllBands_Training_Id_1314.tif
# ✅ Copied and renamed: id_1315.tif → Sentinel_AllBands_Training_Id_1315.tif
# ✅ Copied and renamed: id_1316.tif → Sentinel_AllBands_Training_Id_1316.tif
# ✅ Copied and renamed: id_1318.tif → Sentinel_AllBands_Training_Id_1318.tif
# ✅ Copied and renamed: id_1319.tif → Sentinel_AllBands_Training_Id_1319.tif
# ✅ Copied and renamed: id_1323.tif → Sentinel_AllBands_Training_Id_1323.tif
# ✅ Copied and renamed: id_1324.tif → Sentinel_AllBands_Training_Id_1324.tif
# ✅ Copied and renamed: id_1325.tif → Sentinel_AllBands_Training_Id_1325.tif
# ✅ Copied and renamed: id_1326.tif → Sentinel_AllBands_Training_Id_1326.tif
# ✅ Copied and renamed: id_1328.tif → Sentinel_AllBands_Training_Id_1328.tif
# ✅ Copied and renamed: id_1330.tif → Sentinel_AllBands_Training_Id_1330.tif
# ✅ Copied and renamed: id_1331.tif → Sentinel_AllBands_Training_Id_1331.tif
# ✅ Copied and renamed: id_1332.tif → Sentinel_AllBands_Training_Id_1332.tif
# ✅ Copied and renamed: id_1333.tif → Sentinel_AllBands_Training_Id_1333.tif
# ✅ Copied and renamed: id_1334.tif → Sentinel_AllBands_Training_Id_1334.tif
# ✅ Copied and renamed: id_1335.tif → Sentinel_AllBands_Training_Id_1335.tif
# ✅ Copied and renamed: id_1336.tif → Sentinel_AllBands_Training_Id_1336.tif
# ✅ Copied and renamed: id_1337.tif → Sentinel_AllBands_Training_Id_1337.tif
# ✅ Copied and renamed: id_1338.tif → Sentinel_AllBands_Training_Id_1338.tif
# ✅ Copied and renamed: id_1339.tif → Sentinel_AllBands_Training_Id_1339.tif
# ✅ Copied and renamed: id_1340.tif → Sentinel_AllBands_Training_Id_1340.tif
# ✅ Copied and renamed: id_1341.tif → Sentinel_AllBands_Training_Id_1341.tif
# ✅ Copied and renamed: id_1342.tif → Sentinel_AllBands_Training_Id_1342.tif
# ✅ Copied and renamed: id_1343.tif → Sentinel_AllBands_Training_Id_1343.tif
# ✅ Copied and renamed: id_1344.tif → Sentinel_AllBands_Training_Id_1344.tif
# ✅ Copied and renamed: id_1345.tif → Sentinel_AllBands_Training_Id_1345.tif
# ✅ Copied and renamed: id_1347.tif → Sentinel_AllBands_Training_Id_1347.tif
# ✅ Copied and renamed: id_1348.tif → Sentinel_AllBands_Training_Id_1348.tif
# ✅ Copied and renamed: id_1349.tif → Sentinel_AllBands_Training_Id_1349.tif
# ✅ Copied and renamed: id_1350.tif → Sentinel_AllBands_Training_Id_1350.tif
# ✅ Copied and renamed: id_1351.tif → Sentinel_AllBands_Training_Id_1351.tif
# ✅ Copied and renamed: id_1352.tif → Sentinel_AllBands_Training_Id_1352.tif
# ✅ Copied and renamed: id_1353.tif → Sentinel_AllBands_Training_Id_1353.tif
# ✅ Copied and renamed: id_1355.tif → Sentinel_AllBands_Training_Id_1355.tif
# ✅ Copied and renamed: id_1357.tif → Sentinel_AllBands_Training_Id_1357.tif
# ✅ Copied and renamed: id_1358.tif → Sentinel_AllBands_Training_Id_1358.tif
# ✅ Copied and renamed: id_1359.tif → Sentinel_AllBands_Training_Id_1359.tif
# ✅ Copied and renamed: id_1360.tif → Sentinel_AllBands_Training_Id_1360.tif
# ✅ Copied and renamed: id_1361.tif → Sentinel_AllBands_Training_Id_1361.tif
# ✅ Copied and renamed: id_1363.tif → Sentinel_AllBands_Training_Id_1363.tif
# ✅ Copied and renamed: id_1364.tif → Sentinel_AllBands_Training_Id_1364.tif
# ✅ Copied and renamed: id_1366.tif → Sentinel_AllBands_Training_Id_1366.tif
# ✅ Copied and renamed: id_1368.tif → Sentinel_AllBands_Training_Id_1368.tif
# ✅ Copied and renamed: id_1369.tif → Sentinel_AllBands_Training_Id_1369.tif
# ✅ Copied and renamed: id_1370.tif → Sentinel_AllBands_Training_Id_1370.tif
# ✅ Copied and renamed: id_1371.tif → Sentinel_AllBands_Training_Id_1371.tif
# ✅ Copied and renamed: id_1372.tif → Sentinel_AllBands_Training_Id_1372.tif
# ✅ Copied and renamed: id_1373.tif → Sentinel_AllBands_Training_Id_1373.tif
# ✅ Copied and renamed: id_1374.tif → Sentinel_AllBands_Training_Id_1374.tif
# ✅ Copied and renamed: id_1375.tif → Sentinel_AllBands_Training_Id_1375.tif
# ✅ Copied and renamed: id_1376.tif → Sentinel_AllBands_Training_Id_1376.tif
# ✅ Copied and renamed: id_1378.tif → Sentinel_AllBands_Training_Id_1378.tif
# ✅ Copied and renamed: id_1380.tif → Sentinel_AllBands_Training_Id_1380.tif
# ✅ Copied and renamed: id_1381.tif → Sentinel_AllBands_Training_Id_1381.tif
# ✅ Copied and renamed: id_1382.tif → Sentinel_AllBands_Training_Id_1382.tif
# ✅ Copied and renamed: id_1383.tif → Sentinel_AllBands_Training_Id_1383.tif
# ✅ Copied and renamed: id_1384.tif → Sentinel_AllBands_Training_Id_1384.tif
# ✅ Copied and renamed: id_1385.tif → Sentinel_AllBands_Training_Id_1385.tif
# ✅ Copied and renamed: id_1386.tif → Sentinel_AllBands_Training_Id_1386.tif
# ✅ Copied and renamed: id_1387.tif → Sentinel_AllBands_Training_Id_1387.tif
# ✅ Copied and renamed: id_1389.tif → Sentinel_AllBands_Training_Id_1389.tif
# ✅ Copied and renamed: id_1392.tif → Sentinel_AllBands_Training_Id_1392.tif
# ✅ Copied and renamed: id_1396.tif → Sentinel_AllBands_Training_Id_1396.tif
# ✅ Copied and renamed: id_1397.tif → Sentinel_AllBands_Training_Id_1397.tif
# ✅ Copied and renamed: id_1399.tif → Sentinel_AllBands_Training_Id_1399.tif
# ✅ Copied and renamed: id_1400.tif → Sentinel_AllBands_Training_Id_1400.tif
# ✅ Copied and renamed: id_1401.tif → Sentinel_AllBands_Training_Id_1401.tif
# ✅ Copied and renamed: id_1402.tif → Sentinel_AllBands_Training_Id_1402.tif
# ✅ Copied and renamed: id_1403.tif → Sentinel_AllBands_Training_Id_1403.tif
# ✅ Copied and renamed: id_1404.tif → Sentinel_AllBands_Training_Id_1404.tif
# ✅ Copied and renamed: id_1405.tif → Sentinel_AllBands_Training_Id_1405.tif
# ✅ Copied and renamed: id_1406.tif → Sentinel_AllBands_Training_Id_1406.tif
# ✅ Copied and renamed: id_1407.tif → Sentinel_AllBands_Training_Id_1407.tif
# ✅ Copied and renamed: id_1408.tif → Sentinel_AllBands_Training_Id_1408.tif
# ✅ Copied and renamed: id_1409.tif → Sentinel_AllBands_Training_Id_1409.tif
# ✅ Copied and renamed: id_1410.tif → Sentinel_AllBands_Training_Id_1410.tif
# ✅ Copied and renamed: id_1411.tif → Sentinel_AllBands_Training_Id_1411.tif
# ✅ Copied and renamed: id_1412.tif → Sentinel_AllBands_Training_Id_1412.tif
# ✅ Copied and renamed: id_1413.tif → Sentinel_AllBands_Training_Id_1413.tif
# ✅ Copied and renamed: id_1414.tif → Sentinel_AllBands_Training_Id_1414.tif
# ✅ Copied and renamed: id_1415.tif → Sentinel_AllBands_Training_Id_1415.tif
# ✅ Copied and renamed: id_1416.tif → Sentinel_AllBands_Training_Id_1416.tif
# ✅ Copied and renamed: id_1417.tif → Sentinel_AllBands_Training_Id_1417.tif
# ✅ Copied and renamed: id_1418.tif → Sentinel_AllBands_Training_Id_1418.tif
# ✅ Copied and renamed: id_1419.tif → Sentinel_AllBands_Training_Id_1419.tif
# ✅ Copied and renamed: id_1420.tif → Sentinel_AllBands_Training_Id_1420.tif
# ✅ Copied and renamed: id_1421.tif → Sentinel_AllBands_Training_Id_1421.tif
# ✅ Copied and renamed: id_1423.tif → Sentinel_AllBands_Training_Id_1423.tif
# ✅ Copied and renamed: id_1424.tif → Sentinel_AllBands_Training_Id_1424.tif
# ✅ Copied and renamed: id_1427.tif → Sentinel_AllBands_Training_Id_1427.tif
# ✅ Copied and renamed: id_1428.tif → Sentinel_AllBands_Training_Id_1428.tif
# ✅ Copied and renamed: id_1429.tif → Sentinel_AllBands_Training_Id_1429.tif
# ✅ Copied and renamed: id_1430.tif → Sentinel_AllBands_Training_Id_1430.tif
# ✅ Copied and renamed: id_1431.tif → Sentinel_AllBands_Training_Id_1431.tif
# ✅ Copied and renamed: id_1432.tif → Sentinel_AllBands_Training_Id_1432.tif
# ✅ Copied and renamed: id_1433.tif → Sentinel_AllBands_Training_Id_1433.tif
# ✅ Copied and renamed: id_1434.tif → Sentinel_AllBands_Training_Id_1434.tif
# ✅ Copied and renamed: id_1435.tif → Sentinel_AllBands_Training_Id_1435.tif
# ✅ Copied and renamed: id_1436.tif → Sentinel_AllBands_Training_Id_1436.tif
# ✅ Copied and renamed: id_1437.tif → Sentinel_AllBands_Training_Id_1437.tif
# ✅ Copied and renamed: id_1438.tif → Sentinel_AllBands_Training_Id_1438.tif
# ✅ Copied and renamed: id_1439.tif → Sentinel_AllBands_Training_Id_1439.tif
# ✅ Copied and renamed: id_1440.tif → Sentinel_AllBands_Training_Id_1440.tif
# ✅ Copied and renamed: id_1441.tif → Sentinel_AllBands_Training_Id_1441.tif
# ✅ Copied and renamed: id_1442.tif → Sentinel_AllBands_Training_Id_1442.tif
# ✅ Copied and renamed: id_1444.tif → Sentinel_AllBands_Training_Id_1444.tif
# ✅ Copied and renamed: id_1445.tif → Sentinel_AllBands_Training_Id_1445.tif
# ✅ Copied and renamed: id_1446.tif → Sentinel_AllBands_Training_Id_1446.tif
# ✅ Copied and renamed: id_1447.tif → Sentinel_AllBands_Training_Id_1447.tif
# ✅ Copied and renamed: id_1448.tif → Sentinel_AllBands_Training_Id_1448.tif
# ✅ Copied and renamed: id_1449.tif → Sentinel_AllBands_Training_Id_1449.tif
# ✅ Copied and renamed: id_1450.tif → Sentinel_AllBands_Training_Id_1450.tif
# ✅ Copied and renamed: id_1451.tif → Sentinel_AllBands_Training_Id_1451.tif
# ✅ Copied and renamed: id_1453.tif → Sentinel_AllBands_Training_Id_1453.tif
# ✅ Copied and renamed: id_1454.tif → Sentinel_AllBands_Training_Id_1454.tif
# ✅ Copied and renamed: id_1455.tif → Sentinel_AllBands_Training_Id_1455.tif
# ✅ Copied and renamed: id_1457.tif → Sentinel_AllBands_Training_Id_1457.tif
# ✅ Copied and renamed: id_1458.tif → Sentinel_AllBands_Training_Id_1458.tif
# ✅ Copied and renamed: id_1459.tif → Sentinel_AllBands_Training_Id_1459.tif
# ✅ Copied and renamed: id_1460.tif → Sentinel_AllBands_Training_Id_1460.tif
# ✅ Copied and renamed: id_1461.tif → Sentinel_AllBands_Training_Id_1461.tif
# ✅ Copied and renamed: id_1462.tif → Sentinel_AllBands_Training_Id_1462.tif
# ✅ Copied and renamed: id_1463.tif → Sentinel_AllBands_Training_Id_1463.tif
# ✅ Copied and renamed: id_1464.tif → Sentinel_AllBands_Training_Id_1464.tif
# ✅ Copied and renamed: id_1465.tif → Sentinel_AllBands_Training_Id_1465.tif
# ✅ Copied and renamed: id_1466.tif → Sentinel_AllBands_Training_Id_1466.tif
# ✅ Copied and renamed: id_1467.tif → Sentinel_AllBands_Training_Id_1467.tif
# ✅ Copied and renamed: id_1468.tif → Sentinel_AllBands_Training_Id_1468.tif
# ✅ Copied and renamed: id_1469.tif → Sentinel_AllBands_Training_Id_1469.tif
# ✅ Copied and renamed: id_1470.tif → Sentinel_AllBands_Training_Id_1470.tif
# ✅ Copied and renamed: id_1471.tif → Sentinel_AllBands_Training_Id_1471.tif
# ✅ Copied and renamed: id_1472.tif → Sentinel_AllBands_Training_Id_1472.tif
# ✅ Copied and renamed: id_1473.tif → Sentinel_AllBands_Training_Id_1473.tif
# ✅ Copied and renamed: id_1474.tif → Sentinel_AllBands_Training_Id_1474.tif
# ✅ Copied and renamed: id_1475.tif → Sentinel_AllBands_Training_Id_1475.tif
# ✅ Copied and renamed: id_1476.tif → Sentinel_AllBands_Training_Id_1476.tif
# ✅ Copied and renamed: id_1477.tif → Sentinel_AllBands_Training_Id_1477.tif
# ✅ Copied and renamed: id_1479.tif → Sentinel_AllBands_Training_Id_1479.tif
# ✅ Copied and renamed: id_1480.tif → Sentinel_AllBands_Training_Id_1480.tif
# ✅ Copied and renamed: id_1481.tif → Sentinel_AllBands_Training_Id_1481.tif
# ✅ Copied and renamed: id_1482.tif → Sentinel_AllBands_Training_Id_1482.tif
# ✅ Copied and renamed: id_1483.tif → Sentinel_AllBands_Training_Id_1483.tif
# ✅ Copied and renamed: id_1484.tif → Sentinel_AllBands_Training_Id_1484.tif
# ✅ Copied and renamed: id_1485.tif → Sentinel_AllBands_Training_Id_1485.tif
# ✅ Copied and renamed: id_1486.tif → Sentinel_AllBands_Training_Id_1486.tif
# ✅ Copied and renamed: id_1487.tif → Sentinel_AllBands_Training_Id_1487.tif
# ✅ Copied and renamed: id_1488.tif → Sentinel_AllBands_Training_Id_1488.tif
# ✅ Copied and renamed: id_1490.tif → Sentinel_AllBands_Training_Id_1490.tif
# ✅ Copied and renamed: id_1491.tif → Sentinel_AllBands_Training_Id_1491.tif
# ✅ Copied and renamed: id_1492.tif → Sentinel_AllBands_Training_Id_1492.tif
# ✅ Copied and renamed: id_1493.tif → Sentinel_AllBands_Training_Id_1493.tif
# ✅ Copied and renamed: id_1494.tif → Sentinel_AllBands_Training_Id_1494.tif
# ✅ Copied and renamed: id_1496.tif → Sentinel_AllBands_Training_Id_1496.tif
# ✅ Copied and renamed: id_1497.tif → Sentinel_AllBands_Training_Id_1497.tif
# ✅ Copied and renamed: id_1498.tif → Sentinel_AllBands_Training_Id_1498.tif
# ✅ Copied and renamed: id_1500.tif → Sentinel_AllBands_Training_Id_1500.tif
# ✅ Copied and renamed: id_1501.tif → Sentinel_AllBands_Training_Id_1501.tif
# ✅ Copied and renamed: id_1502.tif → Sentinel_AllBands_Training_Id_1502.tif
# ✅ Copied and renamed: id_1503.tif → Sentinel_AllBands_Training_Id_1503.tif
# ✅ Copied and renamed: id_1504.tif → Sentinel_AllBands_Training_Id_1504.tif
# ✅ Copied and renamed: id_1505.tif → Sentinel_AllBands_Training_Id_1505.tif
# ✅ Copied and renamed: id_1506.tif → Sentinel_AllBands_Training_Id_1506.tif
# ✅ Copied and renamed: id_1507.tif → Sentinel_AllBands_Training_Id_1507.tif
# ✅ Copied and renamed: id_1508.tif → Sentinel_AllBands_Training_Id_1508.tif
# ✅ Copied and renamed: id_1509.tif → Sentinel_AllBands_Training_Id_1509.tif
# ✅ Copied and renamed: id_1510.tif → Sentinel_AllBands_Training_Id_1510.tif
# ✅ Copied and renamed: id_1511.tif → Sentinel_AllBands_Training_Id_1511.tif
# ✅ Copied and renamed: id_1512.tif → Sentinel_AllBands_Training_Id_1512.tif
# ✅ Copied and renamed: id_1513.tif → Sentinel_AllBands_Training_Id_1513.tif
# ✅ Copied and renamed: id_1514.tif → Sentinel_AllBands_Training_Id_1514.tif
# ✅ Copied and renamed: id_1515.tif → Sentinel_AllBands_Training_Id_1515.tif
# ✅ Copied and renamed: id_1516.tif → Sentinel_AllBands_Training_Id_1516.tif
# ✅ Copied and renamed: id_1518.tif → Sentinel_AllBands_Training_Id_1518.tif
# ✅ Copied and renamed: id_1519.tif → Sentinel_AllBands_Training_Id_1519.tif
# ✅ Copied and renamed: id_1520.tif → Sentinel_AllBands_Training_Id_1520.tif
# ✅ Copied and renamed: id_1522.tif → Sentinel_AllBands_Training_Id_1522.tif
# ✅ Copied and renamed: id_1524.tif → Sentinel_AllBands_Training_Id_1524.tif
# ✅ Copied and renamed: id_1525.tif → Sentinel_AllBands_Training_Id_1525.tif
# ✅ Copied and renamed: id_1526.tif → Sentinel_AllBands_Training_Id_1526.tif
# ✅ Copied and renamed: id_1527.tif → Sentinel_AllBands_Training_Id_1527.tif
# ✅ Copied and renamed: id_1528.tif → Sentinel_AllBands_Training_Id_1528.tif
# ✅ Copied and renamed: id_1529.tif → Sentinel_AllBands_Training_Id_1529.tif
# ✅ Copied and renamed: id_1530.tif → Sentinel_AllBands_Training_Id_1530.tif
# ✅ Copied and renamed: id_1531.tif → Sentinel_AllBands_Training_Id_1531.tif
# ✅ Copied and renamed: id_1532.tif → Sentinel_AllBands_Training_Id_1532.tif
# ✅ Copied and renamed: id_1533.tif → Sentinel_AllBands_Training_Id_1533.tif
# ✅ Copied and renamed: id_1535.tif → Sentinel_AllBands_Training_Id_1535.tif
# ✅ Copied and renamed: id_1537.tif → Sentinel_AllBands_Training_Id_1537.tif
# ✅ Copied and renamed: id_1538.tif → Sentinel_AllBands_Training_Id_1538.tif
# ✅ Copied and renamed: id_1539.tif → Sentinel_AllBands_Training_Id_1539.tif
# ✅ Copied and renamed: id_1540.tif → Sentinel_AllBands_Training_Id_1540.tif
# ✅ Copied and renamed: id_1541.tif → Sentinel_AllBands_Training_Id_1541.tif
# ✅ Copied and renamed: id_1542.tif → Sentinel_AllBands_Training_Id_1542.tif
# ✅ Copied and renamed: id_1543.tif → Sentinel_AllBands_Training_Id_1543.tif
# ✅ Copied and renamed: id_1544.tif → Sentinel_AllBands_Training_Id_1544.tif
# ✅ Copied and renamed: id_1587.tif → Sentinel_AllBands_Training_Id_1587.tif
# ✅ Copied and renamed: id_1588.tif → Sentinel_AllBands_Training_Id_1588.tif
# ✅ Copied and renamed: id_1589.tif → Sentinel_AllBands_Training_Id_1589.tif
# ✅ Copied and renamed: id_1590.tif → Sentinel_AllBands_Training_Id_1590.tif
# ✅ Copied and renamed: id_1591.tif → Sentinel_AllBands_Training_Id_1591.tif
# ✅ Copied and renamed: id_1592.tif → Sentinel_AllBands_Training_Id_1592.tif
# ✅ Copied and renamed: id_1593.tif → Sentinel_AllBands_Training_Id_1593.tif
# ✅ Copied and renamed: id_1594.tif → Sentinel_AllBands_Training_Id_1594.tif
# ✅ Copied and renamed: id_1595.tif → Sentinel_AllBands_Training_Id_1595.tif
# ✅ Copied and renamed: id_1596.tif → Sentinel_AllBands_Training_Id_1596.tif
# ✅ Copied and renamed: id_1597.tif → Sentinel_AllBands_Training_Id_1597.tif
# ✅ Copied and renamed: id_1598.tif → Sentinel_AllBands_Training_Id_1598.tif
# ✅ Copied and renamed: id_1599.tif → Sentinel_AllBands_Training_Id_1599.tif
# ✅ Copied and renamed: id_1600.tif → Sentinel_AllBands_Training_Id_1600.tif
# ✅ Copied and renamed: id_1601.tif → Sentinel_AllBands_Training_Id_1601.tif
# ✅ Copied and renamed: id_1602.tif → Sentinel_AllBands_Training_Id_1602.tif
# ✅ Copied and renamed: id_1603.tif → Sentinel_AllBands_Training_Id_1603.tif
# ✅ Copied and renamed: id_1604.tif → Sentinel_AllBands_Training_Id_1604.tif
# ✅ Copied and renamed: id_1605.tif → Sentinel_AllBands_Training_Id_1605.tif
# ✅ Copied and renamed: id_1606.tif → Sentinel_AllBands_Training_Id_1606.tif
# ✅ Copied and renamed: id_1607.tif → Sentinel_AllBands_Training_Id_1607.tif
# ✅ Copied and renamed: id_1608.tif → Sentinel_AllBands_Training_Id_1608.tif
# ✅ Copied and renamed: id_1609.tif → Sentinel_AllBands_Training_Id_1609.tif
# ✅ Copied and renamed: id_1610.tif → Sentinel_AllBands_Training_Id_1610.tif
# ✅ Copied and renamed: id_1611.tif → Sentinel_AllBands_Training_Id_1611.tif
# ✅ Copied and renamed: id_1615.tif → Sentinel_AllBands_Training_Id_1615.tif
# ✅ Copied and renamed: id_1616.tif → Sentinel_AllBands_Training_Id_1616.tif
# ✅ Copied and renamed: id_1617.tif → Sentinel_AllBands_Training_Id_1617.tif
# ✅ Copied and renamed: id_1618.tif → Sentinel_AllBands_Training_Id_1618.tif
# ✅ Copied and renamed: id_1619.tif → Sentinel_AllBands_Training_Id_1619.tif
# ✅ Copied and renamed: id_1620.tif → Sentinel_AllBands_Training_Id_1620.tif
# ✅ Copied and renamed: id_1621.tif → Sentinel_AllBands_Training_Id_1621.tif
# ✅ Copied and renamed: id_1622.tif → Sentinel_AllBands_Training_Id_1622.tif
# ✅ Copied and renamed: id_1623.tif → Sentinel_AllBands_Training_Id_1623.tif
# ✅ Copied and renamed: id_1624.tif → Sentinel_AllBands_Training_Id_1624.tif
# ✅ Copied and renamed: id_1625.tif → Sentinel_AllBands_Training_Id_1625.tif
# ✅ Copied and renamed: id_1626.tif → Sentinel_AllBands_Training_Id_1626.tif
# ✅ Copied and renamed: id_1627.tif → Sentinel_AllBands_Training_Id_1627.tif
# ✅ Copied and renamed: id_1628.tif → Sentinel_AllBands_Training_Id_1628.tif
# ✅ Copied and renamed: id_1629.tif → Sentinel_AllBands_Training_Id_1629.tif
# ✅ Copied and renamed: id_1630.tif → Sentinel_AllBands_Training_Id_1630.tif
# ✅ Copied and renamed: id_1631.tif → Sentinel_AllBands_Training_Id_1631.tif
# ✅ Copied and renamed: id_1634.tif → Sentinel_AllBands_Training_Id_1634.tif
# ✅ Copied and renamed: id_1635.tif → Sentinel_AllBands_Training_Id_1635.tif
# ✅ Copied and renamed: id_1636.tif → Sentinel_AllBands_Training_Id_1636.tif
# ✅ Copied and renamed: id_1637.tif → Sentinel_AllBands_Training_Id_1637.tif
# ✅ Copied and renamed: id_1638.tif → Sentinel_AllBands_Training_Id_1638.tif
# ✅ Copied and renamed: id_1639.tif → Sentinel_AllBands_Training_Id_1639.tif
# ✅ Copied and renamed: id_1640.tif → Sentinel_AllBands_Training_Id_1640.tif
# ✅ Copied and renamed: id_1641.tif → Sentinel_AllBands_Training_Id_1641.tif
# ✅ Copied and renamed: id_1642.tif → Sentinel_AllBands_Training_Id_1642.tif
# ✅ Copied and renamed: id_1643.tif → Sentinel_AllBands_Training_Id_1643.tif
# ✅ Copied and renamed: id_1644.tif → Sentinel_AllBands_Training_Id_1644.tif
# ✅ Copied and renamed: id_1645.tif → Sentinel_AllBands_Training_Id_1645.tif
# ✅ Copied and renamed: id_1646.tif → Sentinel_AllBands_Training_Id_1646.tif
# ✅ Copied and renamed: id_1647.tif → Sentinel_AllBands_Training_Id_1647.tif
# ✅ Copied and renamed: id_1649.tif → Sentinel_AllBands_Training_Id_1649.tif
# ✅ Copied and renamed: id_1650.tif → Sentinel_AllBands_Training_Id_1650.tif
# ✅ Copied and renamed: id_1000.tif → Sentinel_AllBands_Training_Id_1000.tif
# ✅ Copied and renamed: id_1001.tif → Sentinel_AllBands_Training_Id_1001.tif
# ✅ Copied and renamed: id_1002.tif → Sentinel_AllBands_Training_Id_1002.tif
# ✅ Copied and renamed: id_1003.tif → Sentinel_AllBands_Training_Id_1003.tif
# ✅ Copied and renamed: id_1005.tif → Sentinel_AllBands_Training_Id_1005.tif
# ✅ Copied and renamed: id_1006.tif → Sentinel_AllBands_Training_Id_1006.tif
# ✅ Copied and renamed: id_1008.tif → Sentinel_AllBands_Training_Id_1008.tif
# ✅ Copied and renamed: id_1009.tif → Sentinel_AllBands_Training_Id_1009.tif
# ✅ Copied and renamed: id_1011.tif → Sentinel_AllBands_Training_Id_1011.tif
# ✅ Copied and renamed: id_1012.tif → Sentinel_AllBands_Training_Id_1012.tif
# ✅ Copied and renamed: id_1013.tif → Sentinel_AllBands_Training_Id_1013.tif
# ✅ Copied and renamed: id_1014.tif → Sentinel_AllBands_Training_Id_1014.tif
# ✅ Copied and renamed: id_1017.tif → Sentinel_AllBands_Training_Id_1017.tif
# ✅ Copied and renamed: id_1018.tif → Sentinel_AllBands_Training_Id_1018.tif
# ✅ Copied and renamed: id_1020.tif → Sentinel_AllBands_Training_Id_1020.tif
# ✅ Copied and renamed: id_1022.tif → Sentinel_AllBands_Training_Id_1022.tif
# ✅ Copied and renamed: id_1023.tif → Sentinel_AllBands_Training_Id_1023.tif
# ✅ Copied and renamed: id_1024.tif → Sentinel_AllBands_Training_Id_1024.tif
# ✅ Copied and renamed: id_1025.tif → Sentinel_AllBands_Training_Id_1025.tif
# ✅ Copied and renamed: id_1028.tif → Sentinel_AllBands_Training_Id_1028.tif
# ✅ Copied and renamed: id_1029.tif → Sentinel_AllBands_Training_Id_1029.tif
# ✅ Copied and renamed: id_1030.tif → Sentinel_AllBands_Training_Id_1030.tif
# ✅ Copied and renamed: id_1031.tif → Sentinel_AllBands_Training_Id_1031.tif
# ✅ Copied and renamed: id_1032.tif → Sentinel_AllBands_Training_Id_1032.tif
# ✅ Copied and renamed: id_1033.tif → Sentinel_AllBands_Training_Id_1033.tif
# ✅ Copied and renamed: id_1034.tif → Sentinel_AllBands_Training_Id_1034.tif
# ✅ Copied and renamed: id_1035.tif → Sentinel_AllBands_Training_Id_1035.tif
# ✅ Copied and renamed: id_1036.tif → Sentinel_AllBands_Training_Id_1036.tif
# ✅ Copied and renamed: id_1037.tif → Sentinel_AllBands_Training_Id_1037.tif
# ✅ Copied and renamed: id_1039.tif → Sentinel_AllBands_Training_Id_1039.tif
# ✅ Copied and renamed: id_1040.tif → Sentinel_AllBands_Training_Id_1040.tif
# ✅ Copied and renamed: id_1042.tif → Sentinel_AllBands_Training_Id_1042.tif
# ✅ Copied and renamed: id_1046.tif → Sentinel_AllBands_Training_Id_1046.tif
# ✅ Copied and renamed: id_1047.tif → Sentinel_AllBands_Training_Id_1047.tif
# ✅ Copied and renamed: id_1049.tif → Sentinel_AllBands_Training_Id_1049.tif
# ✅ Copied and renamed: id_1050.tif → Sentinel_AllBands_Training_Id_1050.tif
# ✅ Copied and renamed: id_1051.tif → Sentinel_AllBands_Training_Id_1051.tif
# ✅ Copied and renamed: id_1052.tif → Sentinel_AllBands_Training_Id_1052.tif
# ✅ Copied and renamed: id_1053.tif → Sentinel_AllBands_Training_Id_1053.tif
# ✅ Copied and renamed: id_1054.tif → Sentinel_AllBands_Training_Id_1054.tif
# ✅ Copied and renamed: id_1056.tif → Sentinel_AllBands_Training_Id_1056.tif
# ✅ Copied and renamed: id_1057.tif → Sentinel_AllBands_Training_Id_1057.tif
# ✅ Copied and renamed: id_1058.tif → Sentinel_AllBands_Training_Id_1058.tif
# ✅ Copied and renamed: id_1059.tif → Sentinel_AllBands_Training_Id_1059.tif
# ✅ Copied and renamed: id_1060.tif → Sentinel_AllBands_Training_Id_1060.tif
# ✅ Copied and renamed: id_1061.tif → Sentinel_AllBands_Training_Id_1061.tif
# ✅ Copied and renamed: id_1062.tif → Sentinel_AllBands_Training_Id_1062.tif
# ✅ Copied and renamed: id_1063.tif → Sentinel_AllBands_Training_Id_1063.tif
# ✅ Copied and renamed: id_1064.tif → Sentinel_AllBands_Training_Id_1064.tif
# ✅ Copied and renamed: id_1065.tif → Sentinel_AllBands_Training_Id_1065.tif
# ✅ Copied and renamed: id_1066.tif → Sentinel_AllBands_Training_Id_1066.tif
# ✅ Copied and renamed: id_1067.tif → Sentinel_AllBands_Training_Id_1067.tif
# ✅ Copied and renamed: id_1070.tif → Sentinel_AllBands_Training_Id_1070.tif
# ✅ Copied and renamed: id_1072.tif → Sentinel_AllBands_Training_Id_1072.tif
# ✅ Copied and renamed: id_1073.tif → Sentinel_AllBands_Training_Id_1073.tif
# ✅ Copied and renamed: id_1074.tif → Sentinel_AllBands_Training_Id_1074.tif
# ✅ Copied and renamed: id_1075.tif → Sentinel_AllBands_Training_Id_1075.tif
# ✅ Copied and renamed: id_1076.tif → Sentinel_AllBands_Training_Id_1076.tif
# ✅ Copied and renamed: id_1077.tif → Sentinel_AllBands_Training_Id_1077.tif
# ✅ Copied and renamed: id_1078.tif → Sentinel_AllBands_Training_Id_1078.tif
# ✅ Copied and renamed: id_1079.tif → Sentinel_AllBands_Training_Id_1079.tif
# ✅ Copied and renamed: id_1080.tif → Sentinel_AllBands_Training_Id_1080.tif
# ✅ Copied and renamed: id_1081.tif → Sentinel_AllBands_Training_Id_1081.tif
# ✅ Copied and renamed: id_1082.tif → Sentinel_AllBands_Training_Id_1082.tif
# ✅ Copied and renamed: id_1084.tif → Sentinel_AllBands_Training_Id_1084.tif
# ✅ Copied and renamed: id_1085.tif → Sentinel_AllBands_Training_Id_1085.tif
# ✅ Copied and renamed: id_1086.tif → Sentinel_AllBands_Training_Id_1086.tif
# ✅ Copied and renamed: id_1087.tif → Sentinel_AllBands_Training_Id_1087.tif
# ✅ Copied and renamed: id_1088.tif → Sentinel_AllBands_Training_Id_1088.tif
# ✅ Copied and renamed: id_1089.tif → Sentinel_AllBands_Training_Id_1089.tif
# ✅ Copied and renamed: id_1090.tif → Sentinel_AllBands_Training_Id_1090.tif
# ✅ Copied and renamed: id_1091.tif → Sentinel_AllBands_Training_Id_1091.tif
# ✅ Copied and renamed: id_1092.tif → Sentinel_AllBands_Training_Id_1092.tif
# ✅ Copied and renamed: id_1093.tif → Sentinel_AllBands_Training_Id_1093.tif
# ✅ Copied and renamed: id_1094.tif → Sentinel_AllBands_Training_Id_1094.tif
# ✅ Copied and renamed: id_1095.tif → Sentinel_AllBands_Training_Id_1095.tif
# ✅ Copied and renamed: id_1096.tif → Sentinel_AllBands_Training_Id_1096.tif
# ✅ Copied and renamed: id_1097.tif → Sentinel_AllBands_Training_Id_1097.tif
# ✅ Copied and renamed: id_1098.tif → Sentinel_AllBands_Training_Id_1098.tif
# ✅ Copied and renamed: id_1099.tif → Sentinel_AllBands_Training_Id_1099.tif
# ✅ Copied and renamed: id_1100.tif → Sentinel_AllBands_Training_Id_1100.tif
# ✅ Copied and renamed: id_1101.tif → Sentinel_AllBands_Training_Id_1101.tif
# ✅ Copied and renamed: id_1103.tif → Sentinel_AllBands_Training_Id_1103.tif
# ✅ Copied and renamed: id_1104.tif → Sentinel_AllBands_Training_Id_1104.tif
# ✅ Copied and renamed: id_1105.tif → Sentinel_AllBands_Training_Id_1105.tif
# ✅ Copied and renamed: id_1106.tif → Sentinel_AllBands_Training_Id_1106.tif
# ✅ Copied and renamed: id_1107.tif → Sentinel_AllBands_Training_Id_1107.tif
# ✅ Copied and renamed: id_1108.tif → Sentinel_AllBands_Training_Id_1108.tif
# ✅ Copied and renamed: id_1109.tif → Sentinel_AllBands_Training_Id_1109.tif
# ✅ Copied and renamed: id_1111.tif → Sentinel_AllBands_Training_Id_1111.tif
# ✅ Copied and renamed: id_1112.tif → Sentinel_AllBands_Training_Id_1112.tif
# ✅ Copied and renamed: id_1113.tif → Sentinel_AllBands_Training_Id_1113.tif
# ✅ Copied and renamed: id_1114.tif → Sentinel_AllBands_Training_Id_1114.tif
# ✅ Copied and renamed: id_1115.tif → Sentinel_AllBands_Training_Id_1115.tif
# ✅ Copied and renamed: id_1116.tif → Sentinel_AllBands_Training_Id_1116.tif
# ✅ Copied and renamed: id_1117.tif → Sentinel_AllBands_Training_Id_1117.tif
# ✅ Copied and renamed: id_1118.tif → Sentinel_AllBands_Training_Id_1118.tif
# ✅ Copied and renamed: id_1119.tif → Sentinel_AllBands_Training_Id_1119.tif
# ✅ Copied and renamed: id_1120.tif → Sentinel_AllBands_Training_Id_1120.tif
# ✅ Copied and renamed: id_1122.tif → Sentinel_AllBands_Training_Id_1122.tif
# ✅ Copied and renamed: id_1123.tif → Sentinel_AllBands_Training_Id_1123.tif
# ✅ Copied and renamed: id_1124.tif → Sentinel_AllBands_Training_Id_1124.tif
# ✅ Copied and renamed: id_1126.tif → Sentinel_AllBands_Training_Id_1126.tif
# ✅ Copied and renamed: id_1127.tif → Sentinel_AllBands_Training_Id_1127.tif
# ✅ Copied and renamed: id_1128.tif → Sentinel_AllBands_Training_Id_1128.tif
# ✅ Copied and renamed: id_1130.tif → Sentinel_AllBands_Training_Id_1130.tif
# ✅ Copied and renamed: id_1133.tif → Sentinel_AllBands_Training_Id_1133.tif
# ✅ Copied and renamed: id_1135.tif → Sentinel_AllBands_Training_Id_1135.tif
# ✅ Copied and renamed: id_1138.tif → Sentinel_AllBands_Training_Id_1138.tif
# ✅ Copied and renamed: id_1140.tif → Sentinel_AllBands_Training_Id_1140.tif
# ✅ Copied and renamed: id_1141.tif → Sentinel_AllBands_Training_Id_1141.tif
# ✅ Copied and renamed: id_1142.tif → Sentinel_AllBands_Training_Id_1142.tif
# ✅ Copied and renamed: id_1143.tif → Sentinel_AllBands_Training_Id_1143.tif
# ✅ Copied and renamed: id_1144.tif → Sentinel_AllBands_Training_Id_1144.tif
# ✅ Copied and renamed: id_1145.tif → Sentinel_AllBands_Training_Id_1145.tif
# ✅ Copied and renamed: id_1146.tif → Sentinel_AllBands_Training_Id_1146.tif
# ✅ Copied and renamed: id_1147.tif → Sentinel_AllBands_Training_Id_1147.tif
# ✅ Copied and renamed: id_1148.tif → Sentinel_AllBands_Training_Id_1148.tif
# ✅ Copied and renamed: id_1149.tif → Sentinel_AllBands_Training_Id_1149.tif
# ✅ Copied and renamed: id_1150.tif → Sentinel_AllBands_Training_Id_1150.tif
# ✅ Copied and renamed: id_1151.tif → Sentinel_AllBands_Training_Id_1151.tif
# ✅ Copied and renamed: id_1152.tif → Sentinel_AllBands_Training_Id_1152.tif
# ✅ Copied and renamed: id_1154.tif → Sentinel_AllBands_Training_Id_1154.tif
# ✅ Copied and renamed: id_1155.tif → Sentinel_AllBands_Training_Id_1155.tif
# ✅ Copied and renamed: id_1157.tif → Sentinel_AllBands_Training_Id_1157.tif
# ✅ Copied and renamed: id_1158.tif → Sentinel_AllBands_Training_Id_1158.tif
# ✅ Copied and renamed: id_1159.tif → Sentinel_AllBands_Training_Id_1159.tif
# ✅ Copied and renamed: id_1160.tif → Sentinel_AllBands_Training_Id_1160.tif
# ✅ Copied and renamed: id_1161.tif → Sentinel_AllBands_Training_Id_1161.tif
# ✅ Copied and renamed: id_1162.tif → Sentinel_AllBands_Training_Id_1162.tif
# ✅ Copied and renamed: id_1163.tif → Sentinel_AllBands_Training_Id_1163.tif
# ✅ Copied and renamed: id_1164.tif → Sentinel_AllBands_Training_Id_1164.tif
# ✅ Copied and renamed: id_1165.tif → Sentinel_AllBands_Training_Id_1165.tif
# ✅ Copied and renamed: id_1166.tif → Sentinel_AllBands_Training_Id_1166.tif
# ✅ Copied and renamed: id_1167.tif → Sentinel_AllBands_Training_Id_1167.tif
# ✅ Copied and renamed: id_1168.tif → Sentinel_AllBands_Training_Id_1168.tif
# ✅ Copied and renamed: id_1169.tif → Sentinel_AllBands_Training_Id_1169.tif
# ✅ Copied and renamed: id_1170.tif → Sentinel_AllBands_Training_Id_1170.tif
# ✅ Copied and renamed: id_1171.tif → Sentinel_AllBands_Training_Id_1171.tif
# ✅ Copied and renamed: id_1172.tif → Sentinel_AllBands_Training_Id_1172.tif
# ✅ Copied and renamed: id_1173.tif → Sentinel_AllBands_Training_Id_1173.tif
# ✅ Copied and renamed: id_1174.tif → Sentinel_AllBands_Training_Id_1174.tif
# ✅ Copied and renamed: id_1176.tif → Sentinel_AllBands_Training_Id_1176.tif
# ✅ Copied and renamed: id_1177.tif → Sentinel_AllBands_Training_Id_1177.tif
# ✅ Copied and renamed: id_1178.tif → Sentinel_AllBands_Training_Id_1178.tif
# ✅ Copied and renamed: id_1179.tif → Sentinel_AllBands_Training_Id_1179.tif
# ✅ Copied and renamed: id_1180.tif → Sentinel_AllBands_Training_Id_1180.tif
# ✅ Copied and renamed: id_1181.tif → Sentinel_AllBands_Training_Id_1181.tif
# ✅ Copied and renamed: id_1182.tif → Sentinel_AllBands_Training_Id_1182.tif
# ✅ Copied and renamed: id_1183.tif → Sentinel_AllBands_Training_Id_1183.tif
# ✅ Copied and renamed: id_1185.tif → Sentinel_AllBands_Training_Id_1185.tif
# ✅ Copied and renamed: id_1187.tif → Sentinel_AllBands_Training_Id_1187.tif
# ✅ Copied and renamed: id_1188.tif → Sentinel_AllBands_Training_Id_1188.tif
# ✅ Copied and renamed: id_1191.tif → Sentinel_AllBands_Training_Id_1191.tif
# ✅ Copied and renamed: id_1192.tif → Sentinel_AllBands_Training_Id_1192.tif
# ✅ Copied and renamed: id_1193.tif → Sentinel_AllBands_Training_Id_1193.tif
# ✅ Copied and renamed: id_1194.tif → Sentinel_AllBands_Training_Id_1194.tif
# ✅ Copied and renamed: id_1196.tif → Sentinel_AllBands_Training_Id_1196.tif
# ✅ Copied and renamed: id_1197.tif → Sentinel_AllBands_Training_Id_1197.tif
# ✅ Copied and renamed: id_1198.tif → Sentinel_AllBands_Training_Id_1198.tif
# ✅ Copied and renamed: id_1200.tif → Sentinel_AllBands_Training_Id_1200.tif
# ✅ Copied and renamed: id_1201.tif → Sentinel_AllBands_Training_Id_1201.tif
# ✅ Copied and renamed: id_1202.tif → Sentinel_AllBands_Training_Id_1202.tif
# ✅ Copied and renamed: id_1203.tif → Sentinel_AllBands_Training_Id_1203.tif
# ✅ Copied and renamed: id_1204.tif → Sentinel_AllBands_Training_Id_1204.tif
# ✅ Copied and renamed: id_1205.tif → Sentinel_AllBands_Training_Id_1205.tif
# ✅ Copied and renamed: id_1206.tif → Sentinel_AllBands_Training_Id_1206.tif
# ✅ Copied and renamed: id_1207.tif → Sentinel_AllBands_Training_Id_1207.tif
# ✅ Copied and renamed: id_1208.tif → Sentinel_AllBands_Training_Id_1208.tif
# ✅ Copied and renamed: id_1209.tif → Sentinel_AllBands_Training_Id_1209.tif
# ✅ Copied and renamed: id_800.tif → Sentinel_AllBands_Training_Id_800.tif
# ✅ Copied and renamed: id_801.tif → Sentinel_AllBands_Training_Id_801.tif
# ✅ Copied and renamed: id_802.tif → Sentinel_AllBands_Training_Id_802.tif
# ✅ Copied and renamed: id_803.tif → Sentinel_AllBands_Training_Id_803.tif
# ✅ Copied and renamed: id_804.tif → Sentinel_AllBands_Training_Id_804.tif
# ✅ Copied and renamed: id_806.tif → Sentinel_AllBands_Training_Id_806.tif
# ✅ Copied and renamed: id_807.tif → Sentinel_AllBands_Training_Id_807.tif
# ✅ Copied and renamed: id_808.tif → Sentinel_AllBands_Training_Id_808.tif
# ✅ Copied and renamed: id_809.tif → Sentinel_AllBands_Training_Id_809.tif
# ✅ Copied and renamed: id_810.tif → Sentinel_AllBands_Training_Id_810.tif
# ✅ Copied and renamed: id_811.tif → Sentinel_AllBands_Training_Id_811.tif
# ✅ Copied and renamed: id_812.tif → Sentinel_AllBands_Training_Id_812.tif
# ✅ Copied and renamed: id_813.tif → Sentinel_AllBands_Training_Id_813.tif
# ✅ Copied and renamed: id_814.tif → Sentinel_AllBands_Training_Id_814.tif
# ✅ Copied and renamed: id_815.tif → Sentinel_AllBands_Training_Id_815.tif
# ✅ Copied and renamed: id_816.tif → Sentinel_AllBands_Training_Id_816.tif
# ✅ Copied and renamed: id_818.tif → Sentinel_AllBands_Training_Id_818.tif
# ✅ Copied and renamed: id_820.tif → Sentinel_AllBands_Training_Id_820.tif
# ✅ Copied and renamed: id_821.tif → Sentinel_AllBands_Training_Id_821.tif
# ✅ Copied and renamed: id_822.tif → Sentinel_AllBands_Training_Id_822.tif
# ✅ Copied and renamed: id_823.tif → Sentinel_AllBands_Training_Id_823.tif
# ✅ Copied and renamed: id_824.tif → Sentinel_AllBands_Training_Id_824.tif
# ✅ Copied and renamed: id_825.tif → Sentinel_AllBands_Training_Id_825.tif
# ✅ Copied and renamed: id_826.tif → Sentinel_AllBands_Training_Id_826.tif
# ✅ Copied and renamed: id_827.tif → Sentinel_AllBands_Training_Id_827.tif
# ✅ Copied and renamed: id_828.tif → Sentinel_AllBands_Training_Id_828.tif
# ✅ Copied and renamed: id_829.tif → Sentinel_AllBands_Training_Id_829.tif
# ✅ Copied and renamed: id_830.tif → Sentinel_AllBands_Training_Id_830.tif
# ✅ Copied and renamed: id_831.tif → Sentinel_AllBands_Training_Id_831.tif
# ✅ Copied and renamed: id_832.tif → Sentinel_AllBands_Training_Id_832.tif
# ✅ Copied and renamed: id_833.tif → Sentinel_AllBands_Training_Id_833.tif
# ✅ Copied and renamed: id_834.tif → Sentinel_AllBands_Training_Id_834.tif
# ✅ Copied and renamed: id_835.tif → Sentinel_AllBands_Training_Id_835.tif
# ✅ Copied and renamed: id_836.tif → Sentinel_AllBands_Training_Id_836.tif
# ✅ Copied and renamed: id_837.tif → Sentinel_AllBands_Training_Id_837.tif
# ✅ Copied and renamed: id_838.tif → Sentinel_AllBands_Training_Id_838.tif
# ✅ Copied and renamed: id_839.tif → Sentinel_AllBands_Training_Id_839.tif
# ✅ Copied and renamed: id_840.tif → Sentinel_AllBands_Training_Id_840.tif
# ✅ Copied and renamed: id_842.tif → Sentinel_AllBands_Training_Id_842.tif
# ✅ Copied and renamed: id_843.tif → Sentinel_AllBands_Training_Id_843.tif
# ✅ Copied and renamed: id_844.tif → Sentinel_AllBands_Training_Id_844.tif
# ✅ Copied and renamed: id_845.tif → Sentinel_AllBands_Training_Id_845.tif
# ✅ Copied and renamed: id_846.tif → Sentinel_AllBands_Training_Id_846.tif
# ✅ Copied and renamed: id_847.tif → Sentinel_AllBands_Training_Id_847.tif
# ✅ Copied and renamed: id_848.tif → Sentinel_AllBands_Training_Id_848.tif
# ✅ Copied and renamed: id_849.tif → Sentinel_AllBands_Training_Id_849.tif
# ✅ Copied and renamed: id_850.tif → Sentinel_AllBands_Training_Id_850.tif
# ✅ Copied and renamed: id_851.tif → Sentinel_AllBands_Training_Id_851.tif
# ✅ Copied and renamed: id_852.tif → Sentinel_AllBands_Training_Id_852.tif
# ✅ Copied and renamed: id_853.tif → Sentinel_AllBands_Training_Id_853.tif
# ✅ Copied and renamed: id_854.tif → Sentinel_AllBands_Training_Id_854.tif
# ✅ Copied and renamed: id_855.tif → Sentinel_AllBands_Training_Id_855.tif
# ✅ Copied and renamed: id_856.tif → Sentinel_AllBands_Training_Id_856.tif
# ✅ Copied and renamed: id_857.tif → Sentinel_AllBands_Training_Id_857.tif
# ✅ Copied and renamed: id_858.tif → Sentinel_AllBands_Training_Id_858.tif
# ✅ Copied and renamed: id_859.tif → Sentinel_AllBands_Training_Id_859.tif
# ✅ Copied and renamed: id_860.tif → Sentinel_AllBands_Training_Id_860.tif
# ✅ Copied and renamed: id_862.tif → Sentinel_AllBands_Training_Id_862.tif
# ✅ Copied and renamed: id_863.tif → Sentinel_AllBands_Training_Id_863.tif
# ✅ Copied and renamed: id_864.tif → Sentinel_AllBands_Training_Id_864.tif
# ✅ Copied and renamed: id_869.tif → Sentinel_AllBands_Training_Id_869.tif
# ✅ Copied and renamed: id_871.tif → Sentinel_AllBands_Training_Id_871.tif
# ✅ Copied and renamed: id_872.tif → Sentinel_AllBands_Training_Id_872.tif
# ✅ Copied and renamed: id_873.tif → Sentinel_AllBands_Training_Id_873.tif
# ✅ Copied and renamed: id_874.tif → Sentinel_AllBands_Training_Id_874.tif
# ✅ Copied and renamed: id_875.tif → Sentinel_AllBands_Training_Id_875.tif
# ✅ Copied and renamed: id_876.tif → Sentinel_AllBands_Training_Id_876.tif
# ✅ Copied and renamed: id_877.tif → Sentinel_AllBands_Training_Id_877.tif
# ✅ Copied and renamed: id_878.tif → Sentinel_AllBands_Training_Id_878.tif
# ✅ Copied and renamed: id_879.tif → Sentinel_AllBands_Training_Id_879.tif
# ✅ Copied and renamed: id_882.tif → Sentinel_AllBands_Training_Id_882.tif
# ✅ Copied and renamed: id_883.tif → Sentinel_AllBands_Training_Id_883.tif
# ✅ Copied and renamed: id_884.tif → Sentinel_AllBands_Training_Id_884.tif
# ✅ Copied and renamed: id_885.tif → Sentinel_AllBands_Training_Id_885.tif
# ✅ Copied and renamed: id_886.tif → Sentinel_AllBands_Training_Id_886.tif
# ✅ Copied and renamed: id_887.tif → Sentinel_AllBands_Training_Id_887.tif
# ✅ Copied and renamed: id_888.tif → Sentinel_AllBands_Training_Id_888.tif
# ✅ Copied and renamed: id_889.tif → Sentinel_AllBands_Training_Id_889.tif
# ✅ Copied and renamed: id_890.tif → Sentinel_AllBands_Training_Id_890.tif
# ✅ Copied and renamed: id_891.tif → Sentinel_AllBands_Training_Id_891.tif
# ✅ Copied and renamed: id_892.tif → Sentinel_AllBands_Training_Id_892.tif
# ✅ Copied and renamed: id_894.tif → Sentinel_AllBands_Training_Id_894.tif
# ✅ Copied and renamed: id_895.tif → Sentinel_AllBands_Training_Id_895.tif
# ✅ Copied and renamed: id_898.tif → Sentinel_AllBands_Training_Id_898.tif
# ✅ Copied and renamed: id_899.tif → Sentinel_AllBands_Training_Id_899.tif
# ✅ Copied and renamed: id_900.tif → Sentinel_AllBands_Training_Id_900.tif
# ✅ Copied and renamed: id_901.tif → Sentinel_AllBands_Training_Id_901.tif
# ✅ Copied and renamed: id_902.tif → Sentinel_AllBands_Training_Id_902.tif
# ✅ Copied and renamed: id_904.tif → Sentinel_AllBands_Training_Id_904.tif
# ✅ Copied and renamed: id_907.tif → Sentinel_AllBands_Training_Id_907.tif
# ✅ Copied and renamed: id_910.tif → Sentinel_AllBands_Training_Id_910.tif
# ✅ Copied and renamed: id_911.tif → Sentinel_AllBands_Training_Id_911.tif
# ✅ Copied and renamed: id_912.tif → Sentinel_AllBands_Training_Id_912.tif
# ✅ Copied and renamed: id_913.tif → Sentinel_AllBands_Training_Id_913.tif
# ✅ Copied and renamed: id_915.tif → Sentinel_AllBands_Training_Id_915.tif
# ✅ Copied and renamed: id_916.tif → Sentinel_AllBands_Training_Id_916.tif
# ✅ Copied and renamed: id_917.tif → Sentinel_AllBands_Training_Id_917.tif
# ✅ Copied and renamed: id_919.tif → Sentinel_AllBands_Training_Id_919.tif
# ✅ Copied and renamed: id_920.tif → Sentinel_AllBands_Training_Id_920.tif
# ✅ Copied and renamed: id_921.tif → Sentinel_AllBands_Training_Id_921.tif
# ✅ Copied and renamed: id_922.tif → Sentinel_AllBands_Training_Id_922.tif
# ✅ Copied and renamed: id_923.tif → Sentinel_AllBands_Training_Id_923.tif
# ✅ Copied and renamed: id_924.tif → Sentinel_AllBands_Training_Id_924.tif
# ✅ Copied and renamed: id_926.tif → Sentinel_AllBands_Training_Id_926.tif
# ✅ Copied and renamed: id_927.tif → Sentinel_AllBands_Training_Id_927.tif
# ✅ Copied and renamed: id_929.tif → Sentinel_AllBands_Training_Id_929.tif
# ✅ Copied and renamed: id_930.tif → Sentinel_AllBands_Training_Id_930.tif
# ✅ Copied and renamed: id_931.tif → Sentinel_AllBands_Training_Id_931.tif
# ✅ Copied and renamed: id_932.tif → Sentinel_AllBands_Training_Id_932.tif
# ✅ Copied and renamed: id_933.tif → Sentinel_AllBands_Training_Id_933.tif
# ✅ Copied and renamed: id_934.tif → Sentinel_AllBands_Training_Id_934.tif
# ✅ Copied and renamed: id_935.tif → Sentinel_AllBands_Training_Id_935.tif
# ✅ Copied and renamed: id_936.tif → Sentinel_AllBands_Training_Id_936.tif
# ✅ Copied and renamed: id_937.tif → Sentinel_AllBands_Training_Id_937.tif
# ✅ Copied and renamed: id_938.tif → Sentinel_AllBands_Training_Id_938.tif
# ✅ Copied and renamed: id_939.tif → Sentinel_AllBands_Training_Id_939.tif
# ✅ Copied and renamed: id_940.tif → Sentinel_AllBands_Training_Id_940.tif
# ✅ Copied and renamed: id_941.tif → Sentinel_AllBands_Training_Id_941.tif
# ✅ Copied and renamed: id_942.tif → Sentinel_AllBands_Training_Id_942.tif
# ✅ Copied and renamed: id_943.tif → Sentinel_AllBands_Training_Id_943.tif
# ✅ Copied and renamed: id_944.tif → Sentinel_AllBands_Training_Id_944.tif
# ✅ Copied and renamed: id_945.tif → Sentinel_AllBands_Training_Id_945.tif
# ✅ Copied and renamed: id_946.tif → Sentinel_AllBands_Training_Id_946.tif
# ✅ Copied and renamed: id_947.tif → Sentinel_AllBands_Training_Id_947.tif
# ✅ Copied and renamed: id_948.tif → Sentinel_AllBands_Training_Id_948.tif
# ✅ Copied and renamed: id_949.tif → Sentinel_AllBands_Training_Id_949.tif
# ✅ Copied and renamed: id_950.tif → Sentinel_AllBands_Training_Id_950.tif
# ✅ Copied and renamed: id_955.tif → Sentinel_AllBands_Training_Id_955.tif
# ✅ Copied and renamed: id_956.tif → Sentinel_AllBands_Training_Id_956.tif
# ✅ Copied and renamed: id_959.tif → Sentinel_AllBands_Training_Id_959.tif
# ✅ Copied and renamed: id_960.tif → Sentinel_AllBands_Training_Id_960.tif
# ✅ Copied and renamed: id_961.tif → Sentinel_AllBands_Training_Id_961.tif
# ✅ Copied and renamed: id_962.tif → Sentinel_AllBands_Training_Id_962.tif
# ✅ Copied and renamed: id_964.tif → Sentinel_AllBands_Training_Id_964.tif
# ✅ Copied and renamed: id_965.tif → Sentinel_AllBands_Training_Id_965.tif
# ✅ Copied and renamed: id_966.tif → Sentinel_AllBands_Training_Id_966.tif
# ✅ Copied and renamed: id_967.tif → Sentinel_AllBands_Training_Id_967.tif
# ✅ Copied and renamed: id_968.tif → Sentinel_AllBands_Training_Id_968.tif
# ✅ Copied and renamed: id_969.tif → Sentinel_AllBands_Training_Id_969.tif
# ✅ Copied and renamed: id_971.tif → Sentinel_AllBands_Training_Id_971.tif
# ✅ Copied and renamed: id_972.tif → Sentinel_AllBands_Training_Id_972.tif
# ✅ Copied and renamed: id_973.tif → Sentinel_AllBands_Training_Id_973.tif
# ✅ Copied and renamed: id_976.tif → Sentinel_AllBands_Training_Id_976.tif
# ✅ Copied and renamed: id_978.tif → Sentinel_AllBands_Training_Id_978.tif
# ✅ Copied and renamed: id_979.tif → Sentinel_AllBands_Training_Id_979.tif
# ✅ Copied and renamed: id_981.tif → Sentinel_AllBands_Training_Id_981.tif
# ✅ Copied and renamed: id_983.tif → Sentinel_AllBands_Training_Id_983.tif
# ✅ Copied and renamed: id_984.tif → Sentinel_AllBands_Training_Id_984.tif
# ✅ Copied and renamed: id_985.tif → Sentinel_AllBands_Training_Id_985.tif
# ✅ Copied and renamed: id_987.tif → Sentinel_AllBands_Training_Id_987.tif
# ✅ Copied and renamed: id_988.tif → Sentinel_AllBands_Training_Id_988.tif
# ✅ Copied and renamed: id_989.tif → Sentinel_AllBands_Training_Id_989.tif
# ✅ Copied and renamed: id_990.tif → Sentinel_AllBands_Training_Id_990.tif
# ✅ Copied and renamed: id_991.tif → Sentinel_AllBands_Training_Id_991.tif
# ✅ Copied and renamed: id_992.tif → Sentinel_AllBands_Training_Id_992.tif
# ✅ Copied and renamed: id_993.tif → Sentinel_AllBands_Training_Id_993.tif
# ✅ Copied and renamed: id_994.tif → Sentinel_AllBands_Training_Id_994.tif
# ✅ Copied and renamed: id_995.tif → Sentinel_AllBands_Training_Id_995.tif
# ✅ Copied and renamed: id_996.tif → Sentinel_AllBands_Training_Id_996.tif
# ✅ Copied and renamed: id_998.tif → Sentinel_AllBands_Training_Id_998.tif
# ✅ Copied and renamed: id_999.tif → Sentinel_AllBands_Training_Id_999.tif
# ✅ Copied and renamed: id_1210.tif → Sentinel_AllBands_Training_Id_1210.tif
# 🎉 Done copying missing images.

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
import shutil
# Out:
# Mounted at /content/drive

# %%
# Replace these paths with yours
src_folder = "/content/drive/MyDrive/P2 - Amazon ITU - PESU/GEE_Exports_all"
dst_folder = "/content/drive/MyDrive/P2 - Amazon ITU - PESU/Copy_GEE_Exports_all"

# Create destination folder if it doesn't exist
os.makedirs(dst_folder, exist_ok=True)

# Copy only .tif files
for file in os.listdir(src_folder):
    if file.lower().endswith(".tif"):
        shutil.copy(os.path.join(src_folder, file), dst_folder)

print("Copy completed.")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/lib/python3.11/shutil.py in copyfile(src, dst, follow_symlinks)
#     268                         try:
# --> 269                             _fastcopy_sendfile(fsrc, fdst)
#     270                             return dst
#
# /usr/lib/python3.11/shutil.py in _fastcopy_sendfile(fsrc, fdst)
#     163
# --> 164             raise err
#     165         else:
#
# /usr/lib/python3.11/shutil.py in _fastcopy_sendfile(fsrc, fdst)
#     143         try:
# --> 144             sent = os.sendfile(outfd, infd, offset, blocksize)
#     145         except OSError as err:
#
# OSError: [Errno 107] Transport endpoint is not connected: '/content/drive/MyDrive/P2 - Amazon ITU - PESU/GEE_Exports_all/id_89.tif' -> '/content/drive/MyDrive/P2 - Amazon ITU - PESU/Copy_GEE_Exports_all/id_89.tif'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /usr/lib/python3.11/shutil.py in copyfile(src, dst, follow_symlinks)
#     257             try:
# --> 258                 with open(dst, 'wb') as fdst:
#     259                     # macOS
#
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /tmp/ipython-input-4115605649.py in <cell line: 0>()
#       9 for file in os.listdir(src_folder):
#      10     if file.lower().endswith(".tif"):
# ---> 11         shutil.copy(os.path.join(src_folder, file), dst_folder)
#      12
#      13 print("Copy completed.")
#
# /usr/lib/python3.11/shutil.py in copy(src, dst, follow_symlinks)
#     429     if os.path.isdir(dst):
#     430         dst = os.path.join(dst, os.path.basename(src))
# --> 431     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     432     copymode(src, dst, follow_symlinks=follow_symlinks)
#     433     return dst
#
# /usr/lib/python3.11/shutil.py in copyfile(src, dst, follow_symlinks)
#     254         os.symlink(os.readlink(src), dst)
#     255     else:
# --> 256         with open(src, 'rb') as fsrc:
#     257             try:
#     258                 with open(dst, 'wb') as fdst:
#
# OSError: [Errno 107] Transport endpoint is not connected
